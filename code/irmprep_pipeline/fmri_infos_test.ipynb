# %%
import os
import pandas as pd
import numpy as np
import difflib as diff

# %%
data_path = "/mnt/data/romy/hypnomed/MRI_raw"
dicom_path = os.path.join(data_path,'DICOM')
bids_path = os.path.join(data_path,'BIDS')

heudiconv_path = os.path.join(bids_path,'.heudiconv')
bids_info_paths = list()

for _,sub in enumerate(sorted(os.listdir(heudiconv_path))):
    bids_info_paths.append(os.path.join(heudiconv_path,'{}/ses-001/info/dicominfo_ses-001.tsv'.format(sub))) #permet de récupérer les paths des infos pour chaque sujet

# %% [markdown]
# ### Retrive DICOM/BIDS infos for subjects

# %%
def get_dicom_infos(bids_info_paths,print_paths=False):

    #Create 3 dict : 
    dcm_dict_indxs = dict() #store the tsv in df format for each subject
    infos_dict_indxs = dict() #strores the infos of each dicom
    dcm_dict_paths = dict() #stores the paths of the files of interest

    for sub_indx,bid_tsv in enumerate(bids_info_paths,1):
        if print_paths: #print the paths for sanitary check
            print(70*'-')
            print('Getting infos for subject n°{}, stored in {}'.format(sub_indx,bid_tsv))
            print(70*'-')
        infos = pd.read_csv(bid_tsv,sep='\t')
        infos_dict_indxs["Sub-{}".format(sub_indx)]=infos 
        dcm_dict_indxs["Sub-{}".format(sub_indx)]={}
        dcm_dict_paths["Sub-{}".format(sub_indx)]={} 

        t2star_dcm = [type for type in infos.dcm_dir_name if 't2star' in type]
        rs_dcm = [type for type in infos.dcm_dir_name if 'rs' in type]
        t1_dcm = [type for type in infos.dcm_dir_name if '3DT1' in type]
        t2_dcm = [type for type in infos.dcm_dir_name if '3DT2' in type]

        dcm_dict = {'RS':rs_dcm,
                    'T1':t1_dcm,
                    'T2':t2_dcm,
                    'T2*':t2star_dcm}

        
        rs_indxs = list()
        t1_indxs = list()
        t2_indxs = list()
        t2star_indxs = list()
        
        for _,(key,val) in enumerate(zip(dcm_dict.keys(),dcm_dict.values())):
            if print_paths: #print the names of the files for sanitary check
                print("{} files : {}\n".format(key,val))

            if key == 'RS': #get the indx number that corresponds to each RS file :
                rs_indxs.extend([val[i].split('_')[0] for i in range(len(val))])
                dcm_dict_indxs["Sub-{}".format(sub_indx)]['RS'] = rs_indxs
                dcm_dict_paths["Sub-{}".format(sub_indx)]['RS'] = val

            elif key == 'T1':
                t1_indxs.extend([val[i].split('_')[0] for i in range(len(val))])
                dcm_dict_indxs["Sub-{}".format(sub_indx)]['T1'] = t1_indxs
                dcm_dict_paths["Sub-{}".format(sub_indx)]['T1'] = val

            elif key == 'T2':
                t2_indxs.extend([val[i].split('_')[0] for i in range(len(val))])
                dcm_dict_indxs["Sub-{}".format(sub_indx)]['T2'] = t2_indxs
                dcm_dict_paths["Sub-{}".format(sub_indx)]['T2'] = val

            elif key == 'T2*':
                t2star_indxs.extend([val[i].split('_')[0] for i in range(len(val))])
                dcm_dict_indxs["Sub-{}".format(sub_indx)]['T2*'] = t2star_indxs
                dcm_dict_paths["Sub-{}".format(sub_indx)]['T2*'] = val
        
    dcm_df = pd.DataFrame.from_dict(dcm_dict_indxs, orient='index') #convert the dictionnary into dataframes
    return dcm_df,infos_dict_indxs,dcm_dict_paths

# %%
dcm_df,infos_dict_indxs,dcm_dict_paths = get_dicom_infos(bids_info_paths,print_paths=False)

# %%
infos_dict_indxs
# Out:
# {'Sub-1':     total_files_till_now                                   example_dcm_file  \
#  0                    128  1.3.12.2.1107.5.2.43.66012.3000001806040846088...
#  1                    133  1.3.12.2.1107.5.2.43.66012.3000001806040846088...
#  2                    136  1.3.12.2.1107.5.2.43.66012.3000001806040846088...
#  3                    139  1.3.12.2.1107.5.2.43.66012.3000001806040846088...
#  4                    158  1.3.12.2.1107.5.2.43.66012.3000001806040846088...
#  5                    159  1.3.12.2.1107.5.2.43.66012.3000001806040846088...
#  6                    394  1.3.12.2.1107.5.2.43.66012.3000001806040846088...
#  7                    550  1.3.12.2.1107.5.2.43.66012.3000001806040846088...
#  8                    950  1.3.12.2.1107.5.2.43.66012.3000001806040846088...
#  9                   1350  1.3.12.2.1107.5.2.43.66012.3000001806040846088...
#  10                  1558  1.3.12.2.1107.5.2.43.66012.3000001806040846088...
#  11                  1766  1.3.12.2.1107.5.2.43.66012.3000001806040846088...
#  12                  2001  1.3.12.2.1107.5.2.43.66012.3000001806040846088...
#  13                  2150  1.3.12.2.1107.5.2.43.66012.3000001806040846088...
#  14                  2358  1.3.12.2.1107.5.2.43.66012.3000001806040846088...
#  15                  2566  1.3.12.2.1107.5.2.43.66012.3000001806040846088...
#  16                  2801  1.3.12.2.1107.5.2.43.66012.3000001806040846088...
#  17                  2949  1.3.12.2.1107.5.2.43.66012.3000001806040846088...
#  18                  3157  1.3.12.2.1107.5.2.43.66012.3000001806040846088...
#  19                  3365  1.3.12.2.1107.5.2.43.66012.3000001806040846088...
#
#                          series_id                   dcm_dir_name unspecified2  \
#  0                     1-AUTOALIGN                    1_AUTOALIGN            -
#  1                     2-AUTOALIGN            2_AUTOALIGN_MPR_sag            -
#  2                     3-AUTOALIGN            3_AUTOALIGN_MPR_cor            -
#  3                     4-AUTOALIGN            4_AUTOALIGN_MPR_tra            -
#  4              5-LOCA_T1_FL2D_SAG             5_LOCA_T1_FL2D_SAG            -
#  5             7-RUNx_QC_tilt25_AP            7_RUNx_QC_tilt25_AP            -
#  6    8-RUNx_rs_3mmiso_TR2.4_44cpe   8_RUNx_rs_3mmiso_TR2.4_44cpe            -
#  7   10-RUNx_er_3mmiso_TR2.4_44cpe  10_RUNx_er_3mmiso_TR2.4_44cpe            -
#  8             12-anat_t2star_2iso            12_anat_t2star_2iso            -
#  9             13-anat_t2star_2iso            13_anat_t2star_2iso            -
#  10            14-anat_3DT2_0.9iso            14_anat_3DT2_0.9iso            -
#  11            15-anat_3DT2_0.9iso            15_anat_3DT2_0.9iso            -
#  12  16-RUNx_rs_3mmiso_TR2.4_44cpe  16_RUNx_rs_3mmiso_TR2.4_44cpe            -
#  13  18-RUNx_er_3mmiso_TR2.4_44cpe  18_RUNx_er_3mmiso_TR2.4_44cpe            -
#  14            20-anat_3DT1_0.9iso            20_anat_3DT1_0.9iso            -
#  15            21-anat_3DT1_0.9iso            21_anat_3DT1_0.9iso            -
#  16  22-RUNx_rs_3mmiso_TR2.4_44cpe  22_RUNx_rs_3mmiso_TR2.4_44cpe            -
#  17  24-RUNx_er_3mmiso_TR2.4_44cpe  24_RUNx_er_3mmiso_TR2.4_44cpe            -
#  18            26-anat_3DT1_0.9iso            26_anat_3DT1_0.9iso            -
#  19            27-anat_3DT1_0.9iso            27_anat_3DT1_0.9iso            -
#
#     unspecified3  dim1  dim2  dim3  dim4  ...  study_description  \
#  0             -   160   160   128     1  ...    HUMAINS^NEUCOSE
#  1             -   162   162     5     1  ...    HUMAINS^NEUCOSE
#  2             -   162   162     3     1  ...    HUMAINS^NEUCOSE
#  3             -   162   162     3     1  ...    HUMAINS^NEUCOSE
#  4             -   192   192    19     1  ...    HUMAINS^NEUCOSE
#  5             -    72    74    44     1  ...    HUMAINS^NEUCOSE
#  6             -    72    74    44   235  ...    HUMAINS^NEUCOSE
#  7             -    72    74    44   156  ...    HUMAINS^NEUCOSE
#  8             -   108   128   400     1  ...    HUMAINS^NEUCOSE
#  9             -   108   128   400     1  ...    HUMAINS^NEUCOSE
#  10            -   256   256   208     1  ...    HUMAINS^NEUCOSE
#  11            -   256   256   208     1  ...    HUMAINS^NEUCOSE
#  12            -    72    74    44   235  ...    HUMAINS^NEUCOSE
#  13            -    72    74    44   149  ...    HUMAINS^NEUCOSE
#  14            -   256   256   208     1  ...    HUMAINS^NEUCOSE
#  15            -   256   256   208     1  ...    HUMAINS^NEUCOSE
#  16            -    72    74    44   235  ...    HUMAINS^NEUCOSE
#  17            -    72    74    44   148  ...    HUMAINS^NEUCOSE
#  18            -   256   256   208     1  ...    HUMAINS^NEUCOSE
#  19            -   256   256   208     1  ...    HUMAINS^NEUCOSE
#
#      referring_physician_name          series_description  sequence_name  \
#  0                        NaN                   AUTOALIGN      *fl3d1_ns
#  1                        NaN           AUTOALIGN_MPR_sag      *fl3d1_ns
#  2                        NaN           AUTOALIGN_MPR_cor      *fl3d1_ns
#  3                        NaN           AUTOALIGN_MPR_tra      *fl3d1_ns
#  4                        NaN            LOCA_T1_FL2D_SAG         *fl2d1
#  5                        NaN           RUNx_QC_tilt25_AP    epfid2d1_72
#  6                        NaN  RUNx_rs_3mmiso_TR2.4_44cpe    epfid2d1_72
#  7                        NaN  RUNx_er_3mmiso_TR2.4_44cpe    epfid2d1_72
#  8                        NaN            anat_t2star_2iso        *fl2d5r
#  9                        NaN            anat_t2star_2iso        *fl2d5r
#  10                       NaN            anat_3DT2_0.9iso     *spc_314ns
#  11                       NaN            anat_3DT2_0.9iso     *spc_314ns
#  12                       NaN  RUNx_rs_3mmiso_TR2.4_44cpe    epfid2d1_72
#  13                       NaN  RUNx_er_3mmiso_TR2.4_44cpe    epfid2d1_72
#  14                       NaN            anat_3DT1_0.9iso   *tfl3d1_16ns
#  15                       NaN            anat_3DT1_0.9iso   *tfl3d1_16ns
#  16                       NaN  RUNx_rs_3mmiso_TR2.4_44cpe    epfid2d1_72
#  17                       NaN  RUNx_er_3mmiso_TR2.4_44cpe    epfid2d1_72
#  18                       NaN            anat_3DT1_0.9iso   *tfl3d1_16ns
#  19                       NaN            anat_3DT1_0.9iso   *tfl3d1_16ns
#
#                                             image_type accession_number  \
#  0          ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM')       ELSES07842
#  1        ('ORIGINAL', 'PRIMARY', 'MPR', 'ND', 'NORM')       ELSES07842
#  2        ('ORIGINAL', 'PRIMARY', 'MPR', 'ND', 'NORM')       ELSES07842
#  3        ('ORIGINAL', 'PRIMARY', 'MPR', 'ND', 'NORM')       ELSES07842
#  4          ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM')       ELSES07842
#  5   ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM', 'MO...       ELSES07842
#  6   ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM', 'MO...       ELSES07842
#  7   ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM', 'MO...       ELSES07842
#  8          ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM')       ELSES07842
#  9                  ('ORIGINAL', 'PRIMARY', 'P', 'ND')       ELSES07842
#  10                 ('ORIGINAL', 'PRIMARY', 'M', 'ND')       ELSES07842
#  11         ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM')       ELSES07842
#  12  ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM', 'MO...       ELSES07842
#  13  ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM', 'MO...       ELSES07842
#  14                 ('ORIGINAL', 'PRIMARY', 'M', 'ND')       ELSES07842
#  15         ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM')       ELSES07842
#  16  ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM', 'MO...       ELSES07842
#  17  ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM', 'MO...       ELSES07842
#  18                 ('ORIGINAL', 'PRIMARY', 'M', 'ND')       ELSES07842
#  19         ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM')       ELSES07842
#
#     patient_age  patient_sex      date  \
#  0         028Y            M  20180604
#  1         028Y            M  20180604
#  2         028Y            M  20180604
#  3         028Y            M  20180604
#  4         028Y            M  20180604
#  5         028Y            M  20180604
#  6         028Y            M  20180604
#  7         028Y            M  20180604
#  8         028Y            M  20180604
#  9         028Y            M  20180604
#  10        028Y            M  20180604
#  11        028Y            M  20180604
#  12        028Y            M  20180604
#  13        028Y            M  20180604
#  14        028Y            M  20180604
#  15        028Y            M  20180604
#  16        028Y            M  20180604
#  17        028Y            M  20180604
#  18        028Y            M  20180604
#  19        028Y            M  20180604
#
#                                             series_uid
#  0   1.3.12.2.1107.5.2.43.66012.2018060411353876297...
#  1   1.3.12.2.1107.5.2.43.66012.2018060411354435435...
#  2   1.3.12.2.1107.5.2.43.66012.2018060411354435899...
#  3   1.3.12.2.1107.5.2.43.66012.2018060411354436125...
#  4   1.3.12.2.1107.5.2.43.66012.2018060411362792554...
#  5   1.3.12.2.1107.5.2.43.66012.2018060411422491167...
#  6   1.3.12.2.1107.5.2.43.66012.2018060411452962891...
#  7   1.3.12.2.1107.5.2.43.66012.2018060411550722034...
#  8   1.3.12.2.1107.5.2.43.66012.2018060412055738118...
#  9   1.3.12.2.1107.5.2.43.66012.2018060412055738130...
#  10  1.3.12.2.1107.5.2.43.66012.2018060412134423530...
#  11  1.3.12.2.1107.5.2.43.66012.2018060412134431805...
#  12  1.3.12.2.1107.5.2.43.66012.2018060412135183684...
#  13  1.3.12.2.1107.5.2.43.66012.2018060412233186165...
#  14  1.3.12.2.1107.5.2.43.66012.2018060412403654883...
#  15  1.3.12.2.1107.5.2.43.66012.2018060412332821465...
#  16  1.3.12.2.1107.5.2.43.66012.2018060412404426549...
#  17  1.3.12.2.1107.5.2.43.66012.2018060412503885207...
#  18  1.3.12.2.1107.5.2.43.66012.2018060413075790841...
#  19  1.3.12.2.1107.5.2.43.66012.2018060413004922073...
#
#  [20 rows x 26 columns],
#  'Sub-2':     total_files_till_now                                   example_dcm_file  \
#  0                    128  1.3.12.2.1107.5.2.43.66012.3000001807200825264...
#  1                    133  1.3.12.2.1107.5.2.43.66012.3000001807200825264...
#  2                    136  1.3.12.2.1107.5.2.43.66012.3000001807200825264...
#  3                    139  1.3.12.2.1107.5.2.43.66012.3000001807200825264...
#  4                    168  1.3.12.2.1107.5.2.43.66012.3000001807200825264...
#  5                    169  1.3.12.2.1107.5.2.43.66012.3000001807200825264...
#  6                    404  1.3.12.2.1107.5.2.43.66012.3000001807200825264...
#  7                    554  1.3.12.2.1107.5.2.43.66012.3000001807200825264...
#  8                    954  1.3.12.2.1107.5.2.43.66012.3000001807200825264...
#  9                   1354  1.3.12.2.1107.5.2.43.66012.3000001807200825264...
#  10                  1562  1.3.12.2.1107.5.2.43.66012.3000001807200825264...
#  11                  1770  1.3.12.2.1107.5.2.43.66012.3000001807200825264...
#  12                  2005  1.3.12.2.1107.5.2.43.66012.3000001807200825264...
#  13                  2156  1.3.12.2.1107.5.2.43.66012.3000001807200825264...
#  14                  2364  1.3.12.2.1107.5.2.43.66012.3000001807200825264...
#  15                  2572  1.3.12.2.1107.5.2.43.66012.3000001807200825264...
#  16                  2807  1.3.12.2.1107.5.2.43.66012.3000001807200825264...
#  17                  2964  1.3.12.2.1107.5.2.43.66012.3000001807200825264...
#
#                          series_id                   dcm_dir_name unspecified2  \
#  0                     1-AUTOALIGN                    1_AUTOALIGN            -
#  1                     2-AUTOALIGN            2_AUTOALIGN_MPR_sag            -
#  2                     3-AUTOALIGN            3_AUTOALIGN_MPR_cor            -
#  3                     4-AUTOALIGN            4_AUTOALIGN_MPR_tra            -
#  4              5-LOCA_T1_FL2D_SAG             5_LOCA_T1_FL2D_SAG            -
#  5             7-RUNx_QC_tilt25_AP            7_RUNx_QC_tilt25_AP            -
#  6    8-RUNx_rs_3mmiso_TR2.4_44cpe   8_RUNx_rs_3mmiso_TR2.4_44cpe            -
#  7   10-RUNx_er_3mmiso_TR2.4_44cpe  10_RUNx_er_3mmiso_TR2.4_44cpe            -
#  8             12-anat_t2star_2iso            12_anat_t2star_2iso            -
#  9             13-anat_t2star_2iso            13_anat_t2star_2iso            -
#  10            14-anat_3DT2_0.9iso            14_anat_3DT2_0.9iso            -
#  11            15-anat_3DT2_0.9iso            15_anat_3DT2_0.9iso            -
#  12  16-RUNx_rs_3mmiso_TR2.4_44cpe  16_RUNx_rs_3mmiso_TR2.4_44cpe            -
#  13  18-RUNx_er_3mmiso_TR2.4_44cpe  18_RUNx_er_3mmiso_TR2.4_44cpe            -
#  14            20-anat_3DT1_0.9iso            20_anat_3DT1_0.9iso            -
#  15            21-anat_3DT1_0.9iso            21_anat_3DT1_0.9iso            -
#  16  22-RUNx_rs_3mmiso_TR2.4_44cpe  22_RUNx_rs_3mmiso_TR2.4_44cpe            -
#  17  24-RUNx_er_3mmiso_TR2.4_44cpe  24_RUNx_er_3mmiso_TR2.4_44cpe            -
#
#     unspecified3  dim1  dim2  dim3  dim4  ...  study_description  \
#  0             -   160   160   128     1  ...    HUMAINS^NEUCOSE
#  1             -   162   162     5     1  ...    HUMAINS^NEUCOSE
#  2             -   162   162     3     1  ...    HUMAINS^NEUCOSE
#  3             -   162   162     3     1  ...    HUMAINS^NEUCOSE
#  4             -   192   192    29     1  ...    HUMAINS^NEUCOSE
#  5             -    72    74    44     1  ...    HUMAINS^NEUCOSE
#  6             -    72    74    44   235  ...    HUMAINS^NEUCOSE
#  7             -    72    74    44   150  ...    HUMAINS^NEUCOSE
#  8             -   108   128   400     1  ...    HUMAINS^NEUCOSE
#  9             -   108   128   400     1  ...    HUMAINS^NEUCOSE
#  10            -   256   256   208     1  ...    HUMAINS^NEUCOSE
#  11            -   256   256   208     1  ...    HUMAINS^NEUCOSE
#  12            -    72    74    44   235  ...    HUMAINS^NEUCOSE
#  13            -    72    74    44   151  ...    HUMAINS^NEUCOSE
#  14            -   256   256   208     1  ...    HUMAINS^NEUCOSE
#  15            -   256   256   208     1  ...    HUMAINS^NEUCOSE
#  16            -    72    74    44   235  ...    HUMAINS^NEUCOSE
#  17            -    72    74    44   157  ...    HUMAINS^NEUCOSE
#
#      referring_physician_name          series_description  sequence_name  \
#  0                        NaN                   AUTOALIGN      *fl3d1_ns
#  1                        NaN           AUTOALIGN_MPR_sag      *fl3d1_ns
#  2                        NaN           AUTOALIGN_MPR_cor      *fl3d1_ns
#  3                        NaN           AUTOALIGN_MPR_tra      *fl3d1_ns
#  4                        NaN            LOCA_T1_FL2D_SAG         *fl2d1
#  5                        NaN           RUNx_QC_tilt25_AP    epfid2d1_72
#  6                        NaN  RUNx_rs_3mmiso_TR2.4_44cpe    epfid2d1_72
#  7                        NaN  RUNx_er_3mmiso_TR2.4_44cpe    epfid2d1_72
#  8                        NaN            anat_t2star_2iso        *fl2d5r
#  9                        NaN            anat_t2star_2iso        *fl2d5r
#  10                       NaN            anat_3DT2_0.9iso     *spc_314ns
#  11                       NaN            anat_3DT2_0.9iso     *spc_314ns
#  12                       NaN  RUNx_rs_3mmiso_TR2.4_44cpe    epfid2d1_72
#  13                       NaN  RUNx_er_3mmiso_TR2.4_44cpe    epfid2d1_72
#  14                       NaN            anat_3DT1_0.9iso   *tfl3d1_16ns
#  15                       NaN            anat_3DT1_0.9iso   *tfl3d1_16ns
#  16                       NaN  RUNx_rs_3mmiso_TR2.4_44cpe    epfid2d1_72
#  17                       NaN  RUNx_er_3mmiso_TR2.4_44cpe    epfid2d1_72
#
#                                             image_type accession_number  \
#  0          ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM')       LECPA07862
#  1        ('ORIGINAL', 'PRIMARY', 'MPR', 'ND', 'NORM')       LECPA07862
#  2        ('ORIGINAL', 'PRIMARY', 'MPR', 'ND', 'NORM')       LECPA07862
#  3        ('ORIGINAL', 'PRIMARY', 'MPR', 'ND', 'NORM')       LECPA07862
#  4          ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM')       LECPA07862
#  5   ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM', 'MO...       LECPA07862
#  6   ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM', 'MO...       LECPA07862
#  7   ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM', 'MO...       LECPA07862
#  8          ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM')       LECPA07862
#  9                  ('ORIGINAL', 'PRIMARY', 'P', 'ND')       LECPA07862
#  10                 ('ORIGINAL', 'PRIMARY', 'M', 'ND')       LECPA07862
#  11         ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM')       LECPA07862
#  12  ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM', 'MO...       LECPA07862
#  13  ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM', 'MO...       LECPA07862
#  14                 ('ORIGINAL', 'PRIMARY', 'M', 'ND')       LECPA07862
#  15         ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM')       LECPA07862
#  16  ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM', 'MO...       LECPA07862
#  17  ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM', 'MO...       LECPA07862
#
#     patient_age  patient_sex      date  \
#  0         027Y            M  20180719
#  1         027Y            M  20180719
#  2         027Y            M  20180719
#  3         027Y            M  20180719
#  4         027Y            M  20180719
#  5         027Y            M  20180719
#  6         027Y            M  20180719
#  7         027Y            M  20180719
#  8         027Y            M  20180719
#  9         027Y            M  20180719
#  10        027Y            M  20180719
#  11        027Y            M  20180719
#  12        027Y            M  20180719
#  13        027Y            M  20180719
#  14        027Y            M  20180719
#  15        027Y            M  20180719
#  16        027Y            M  20180719
#  17        027Y            M  20180719
#
#                                             series_uid
#  0   1.3.12.2.1107.5.2.43.66012.3000001807200825264...
#  1   1.3.12.2.1107.5.2.43.66012.3000001807200825264...
#  2   1.3.12.2.1107.5.2.43.66012.3000001807200825264...
#  3   1.3.12.2.1107.5.2.43.66012.3000001807200825264...
#  4   1.3.12.2.1107.5.2.43.66012.3000001807200825264...
#  5   1.3.12.2.1107.5.2.43.66012.3000001807200825264...
#  6   1.3.12.2.1107.5.2.43.66012.3000001807200825264...
#  7   1.3.12.2.1107.5.2.43.66012.3000001807200825264...
#  8   1.3.12.2.1107.5.2.43.66012.3000001807200825264...
#  9   1.3.12.2.1107.5.2.43.66012.3000001807200825264...
#  10  1.3.12.2.1107.5.2.43.66012.3000001807200825264...
#  11  1.3.12.2.1107.5.2.43.66012.3000001807200825264...
#  12  1.3.12.2.1107.5.2.43.66012.3000001807200825264...
#  13  1.3.12.2.1107.5.2.43.66012.3000001807200825264...
#  14  1.3.12.2.1107.5.2.43.66012.3000001807200825264...
#  15  1.3.12.2.1107.5.2.43.66012.3000001807200825264...
#  16  1.3.12.2.1107.5.2.43.66012.3000001807200825264...
#  17  1.3.12.2.1107.5.2.43.66012.3000001807200825264...
#
#  [18 rows x 26 columns],
#  'Sub-3':     total_files_till_now                                   example_dcm_file  \
#  0                    128  1.3.12.2.1107.5.2.43.66012.3000001807270804462...
#  1                    133  1.3.12.2.1107.5.2.43.66012.3000001807270804462...
#  2                    136  1.3.12.2.1107.5.2.43.66012.3000001807270804462...
#  3                    139  1.3.12.2.1107.5.2.43.66012.3000001807270804462...
#  4                    168  1.3.12.2.1107.5.2.43.66012.3000001807270804462...
#  5                    169  1.3.12.2.1107.5.2.43.66012.3000001807270804462...
#  6                    404  1.3.12.2.1107.5.2.43.66012.3000001807270804462...
#  7                    555  1.3.12.2.1107.5.2.43.66012.3000001807270804462...
#  8                    955  1.3.12.2.1107.5.2.43.66012.3000001807270804462...
#  9                   1355  1.3.12.2.1107.5.2.43.66012.3000001807270804462...
#  10                  1563  1.3.12.2.1107.5.2.43.66012.3000001807270804462...
#  11                  1771  1.3.12.2.1107.5.2.43.66012.3000001807270804462...
#  12                  2006  1.3.12.2.1107.5.2.43.66012.3000001807270804462...
#  13                  2156  1.3.12.2.1107.5.2.43.66012.3000001807270804462...
#  14                  2364  1.3.12.2.1107.5.2.43.66012.3000001807270804462...
#  15                  2572  1.3.12.2.1107.5.2.43.66012.3000001807270804462...
#  16                  2807  1.3.12.2.1107.5.2.43.66012.3000001807270804462...
#  17                  2958  1.3.12.2.1107.5.2.43.66012.3000001807270804462...
#
#                          series_id                   dcm_dir_name unspecified2  \
#  0                     1-AUTOALIGN                    1_AUTOALIGN            -
#  1                     2-AUTOALIGN            2_AUTOALIGN_MPR_sag            -
#  2                     3-AUTOALIGN            3_AUTOALIGN_MPR_cor            -
#  3                     4-AUTOALIGN            4_AUTOALIGN_MPR_tra            -
#  4              5-LOCA_T1_FL2D_SAG             5_LOCA_T1_FL2D_SAG            -
#  5             7-RUNx_QC_tilt25_AP            7_RUNx_QC_tilt25_AP            -
#  6    8-RUNx_rs_3mmiso_TR2.4_44cpe   8_RUNx_rs_3mmiso_TR2.4_44cpe            -
#  7   10-RUNx_er_3mmiso_TR2.4_44cpe  10_RUNx_er_3mmiso_TR2.4_44cpe            -
#  8             12-anat_t2star_2iso            12_anat_t2star_2iso            -
#  9             13-anat_t2star_2iso            13_anat_t2star_2iso            -
#  10            14-anat_3DT2_0.9iso            14_anat_3DT2_0.9iso            -
#  11            15-anat_3DT2_0.9iso            15_anat_3DT2_0.9iso            -
#  12  16-RUNx_rs_3mmiso_TR2.4_44cpe  16_RUNx_rs_3mmiso_TR2.4_44cpe            -
#  13  18-RUNx_er_3mmiso_TR2.4_44cpe  18_RUNx_er_3mmiso_TR2.4_44cpe            -
#  14            20-anat_3DT1_0.9iso            20_anat_3DT1_0.9iso            -
#  15            21-anat_3DT1_0.9iso            21_anat_3DT1_0.9iso            -
#  16  22-RUNx_rs_3mmiso_TR2.4_44cpe  22_RUNx_rs_3mmiso_TR2.4_44cpe            -
#  17  24-RUNx_er_3mmiso_TR2.4_44cpe  24_RUNx_er_3mmiso_TR2.4_44cpe            -
#
#     unspecified3  dim1  dim2  dim3  dim4  ...  study_description  \
#  0             -   160   160   128     1  ...    HUMAINS^NEUCOSE
#  1             -   162   162     5     1  ...    HUMAINS^NEUCOSE
#  2             -   162   162     3     1  ...    HUMAINS^NEUCOSE
#  3             -   162   162     3     1  ...    HUMAINS^NEUCOSE
#  4             -   192   192    29     1  ...    HUMAINS^NEUCOSE
#  5             -    72    74    44     1  ...    HUMAINS^NEUCOSE
#  6             -    72    74    44   235  ...    HUMAINS^NEUCOSE
#  7             -    72    74    44   151  ...    HUMAINS^NEUCOSE
#  8             -   108   128   400     1  ...    HUMAINS^NEUCOSE
#  9             -   108   128   400     1  ...    HUMAINS^NEUCOSE
#  10            -   256   256   208     1  ...    HUMAINS^NEUCOSE
#  11            -   256   256   208     1  ...    HUMAINS^NEUCOSE
#  12            -    72    74    44   235  ...    HUMAINS^NEUCOSE
#  13            -    72    74    44   150  ...    HUMAINS^NEUCOSE
#  14            -   256   256   208     1  ...    HUMAINS^NEUCOSE
#  15            -   256   256   208     1  ...    HUMAINS^NEUCOSE
#  16            -    72    74    44   235  ...    HUMAINS^NEUCOSE
#  17            -    72    74    44   151  ...    HUMAINS^NEUCOSE
#
#      referring_physician_name          series_description  sequence_name  \
#  0                        NaN                   AUTOALIGN      *fl3d1_ns
#  1                        NaN           AUTOALIGN_MPR_sag      *fl3d1_ns
#  2                        NaN           AUTOALIGN_MPR_cor      *fl3d1_ns
#  3                        NaN           AUTOALIGN_MPR_tra      *fl3d1_ns
#  4                        NaN            LOCA_T1_FL2D_SAG         *fl2d1
#  5                        NaN           RUNx_QC_tilt25_AP    epfid2d1_72
#  6                        NaN  RUNx_rs_3mmiso_TR2.4_44cpe    epfid2d1_72
#  7                        NaN  RUNx_er_3mmiso_TR2.4_44cpe    epfid2d1_72
#  8                        NaN            anat_t2star_2iso        *fl2d5r
#  9                        NaN            anat_t2star_2iso        *fl2d5r
#  10                       NaN            anat_3DT2_0.9iso     *spc_314ns
#  11                       NaN            anat_3DT2_0.9iso     *spc_314ns
#  12                       NaN  RUNx_rs_3mmiso_TR2.4_44cpe    epfid2d1_72
#  13                       NaN  RUNx_er_3mmiso_TR2.4_44cpe    epfid2d1_72
#  14                       NaN            anat_3DT1_0.9iso   *tfl3d1_16ns
#  15                       NaN            anat_3DT1_0.9iso   *tfl3d1_16ns
#  16                       NaN  RUNx_rs_3mmiso_TR2.4_44cpe    epfid2d1_72
#  17                       NaN  RUNx_er_3mmiso_TR2.4_44cpe    epfid2d1_72
#
#                                             image_type accession_number  \
#  0          ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM')              NaN
#  1        ('ORIGINAL', 'PRIMARY', 'MPR', 'ND', 'NORM')              NaN
#  2        ('ORIGINAL', 'PRIMARY', 'MPR', 'ND', 'NORM')              NaN
#  3        ('ORIGINAL', 'PRIMARY', 'MPR', 'ND', 'NORM')              NaN
#  4          ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM')              NaN
#  5   ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM', 'MO...              NaN
#  6   ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM', 'MO...              NaN
#  7   ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM', 'MO...              NaN
#  8          ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM')              NaN
#  9                  ('ORIGINAL', 'PRIMARY', 'P', 'ND')              NaN
#  10                 ('ORIGINAL', 'PRIMARY', 'M', 'ND')              NaN
#  11         ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM')              NaN
#  12  ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM', 'MO...              NaN
#  13  ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM', 'MO...              NaN
#  14                 ('ORIGINAL', 'PRIMARY', 'M', 'ND')              NaN
#  15         ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM')              NaN
#  16  ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM', 'MO...              NaN
#  17  ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM', 'MO...              NaN
#
#     patient_age  patient_sex      date  \
#  0         022Y            F  20180727
#  1         022Y            F  20180727
#  2         022Y            F  20180727
#  3         022Y            F  20180727
#  4         022Y            F  20180727
#  5         022Y            F  20180727
#  6         022Y            F  20180727
#  7         022Y            F  20180727
#  8         022Y            F  20180727
#  9         022Y            F  20180727
#  10        022Y            F  20180727
#  11        022Y            F  20180727
#  12        022Y            F  20180727
#  13        022Y            F  20180727
#  14        022Y            F  20180727
#  15        022Y            F  20180727
#  16        022Y            F  20180727
#  17        022Y            F  20180727
#
#                                             series_uid
#  0   1.3.12.2.1107.5.2.43.66012.2018072711050587029...
#  1   1.3.12.2.1107.5.2.43.66012.2018072711051091068...
#  2   1.3.12.2.1107.5.2.43.66012.2018072711051091114...
#  3   1.3.12.2.1107.5.2.43.66012.2018072711051091136...
#  4   1.3.12.2.1107.5.2.43.66012.2018072711054698403...
#  5   1.3.12.2.1107.5.2.43.66012.2018072711101979435...
#  6   1.3.12.2.1107.5.2.43.66012.2018072711132276846...
#  7   1.3.12.2.1107.5.2.43.66012.2018072711252129721...
#  8   1.3.12.2.1107.5.2.43.66012.2018072711365586482...
#  9   1.3.12.2.1107.5.2.43.66012.2018072711365586483...
#  10  1.3.12.2.1107.5.2.43.66012.2018072711443316659...
#  11  1.3.12.2.1107.5.2.43.66012.2018072711443320606...
#  12  1.3.12.2.1107.5.2.43.66012.2018072711444111815...
#  13  1.3.12.2.1107.5.2.43.66012.2018072711543451362...
#  14  1.3.12.2.1107.5.2.43.66012.2018072712122486796...
#  15  1.3.12.2.1107.5.2.43.66012.2018072712051639561...
#  16  1.3.12.2.1107.5.2.43.66012.2018072712123127728...
#  17  1.3.12.2.1107.5.2.43.66012.2018072712225580889...
#
#  [18 rows x 26 columns],
#  'Sub-4':     total_files_till_now                                   example_dcm_file  \
#  0                    128  1.3.12.2.1107.5.2.43.66012.3000001807200827075...
#  1                    133  1.3.12.2.1107.5.2.43.66012.3000001807200827075...
#  2                    136  1.3.12.2.1107.5.2.43.66012.3000001807200827075...
#  3                    139  1.3.12.2.1107.5.2.43.66012.3000001807200827075...
#  4                    168  1.3.12.2.1107.5.2.43.66012.3000001807200827075...
#  5                    169  1.3.12.2.1107.5.2.43.66012.3000001807200827075...
#  6                    404  1.3.12.2.1107.5.2.43.66012.3000001807200827075...
#  7                    555  1.3.12.2.1107.5.2.43.66012.3000001807200827075...
#  8                    955  1.3.12.2.1107.5.2.43.66012.3000001807200827075...
#  9                   1355  1.3.12.2.1107.5.2.43.66012.3000001807200827075...
#  10                  1563  1.3.12.2.1107.5.2.43.66012.3000001807200827075...
#  11                  1771  1.3.12.2.1107.5.2.43.66012.3000001807200827075...
#  12                  2006  1.3.12.2.1107.5.2.43.66012.3000001807200827075...
#  13                  2157  1.3.12.2.1107.5.2.43.66012.3000001807200827075...
#  14                  2365  1.3.12.2.1107.5.2.43.66012.3000001807200827075...
#  15                  2573  1.3.12.2.1107.5.2.43.66012.3000001807200827075...
#  16                  2808  1.3.12.2.1107.5.2.43.66012.3000001807200827075...
#  17                  2959  1.3.12.2.1107.5.2.43.66012.3000001807200827075...
#
#                          series_id                   dcm_dir_name unspecified2  \
#  0                     1-AUTOALIGN                    1_AUTOALIGN            -
#  1                     2-AUTOALIGN            2_AUTOALIGN_MPR_sag            -
#  2                     3-AUTOALIGN            3_AUTOALIGN_MPR_cor            -
#  3                     4-AUTOALIGN            4_AUTOALIGN_MPR_tra            -
#  4              5-LOCA_T1_FL2D_SAG             5_LOCA_T1_FL2D_SAG            -
#  5             7-RUNx_QC_tilt25_AP            7_RUNx_QC_tilt25_AP            -
#  6    8-RUNx_rs_3mmiso_TR2.4_44cpe   8_RUNx_rs_3mmiso_TR2.4_44cpe            -
#  7   10-RUNx_er_3mmiso_TR2.4_44cpe  10_RUNx_er_3mmiso_TR2.4_44cpe            -
#  8             12-anat_t2star_2iso            12_anat_t2star_2iso            -
#  9             13-anat_t2star_2iso            13_anat_t2star_2iso            -
#  10            14-anat_3DT2_0.9iso            14_anat_3DT2_0.9iso            -
#  11            15-anat_3DT2_0.9iso            15_anat_3DT2_0.9iso            -
#  12  16-RUNx_rs_3mmiso_TR2.4_44cpe  16_RUNx_rs_3mmiso_TR2.4_44cpe            -
#  13  18-RUNx_er_3mmiso_TR2.4_44cpe  18_RUNx_er_3mmiso_TR2.4_44cpe            -
#  14            20-anat_3DT1_0.9iso            20_anat_3DT1_0.9iso            -
#  15            21-anat_3DT1_0.9iso            21_anat_3DT1_0.9iso            -
#  16  22-RUNx_rs_3mmiso_TR2.4_44cpe  22_RUNx_rs_3mmiso_TR2.4_44cpe            -
#  17  24-RUNx_er_3mmiso_TR2.4_44cpe  24_RUNx_er_3mmiso_TR2.4_44cpe            -
#
#     unspecified3  dim1  dim2  dim3  dim4  ...  study_description  \
#  0             -   160   160   128     1  ...    HUMAINS^NEUCOSE
#  1             -   162   162     5     1  ...    HUMAINS^NEUCOSE
#  2             -   162   162     3     1  ...    HUMAINS^NEUCOSE
#  3             -   162   162     3     1  ...    HUMAINS^NEUCOSE
#  4             -   192   192    29     1  ...    HUMAINS^NEUCOSE
#  5             -    72    74    44     1  ...    HUMAINS^NEUCOSE
#  6             -    72    74    44   235  ...    HUMAINS^NEUCOSE
#  7             -    72    74    44   151  ...    HUMAINS^NEUCOSE
#  8             -   108   128   400     1  ...    HUMAINS^NEUCOSE
#  9             -   108   128   400     1  ...    HUMAINS^NEUCOSE
#  10            -   256   256   208     1  ...    HUMAINS^NEUCOSE
#  11            -   256   256   208     1  ...    HUMAINS^NEUCOSE
#  12            -    72    74    44   235  ...    HUMAINS^NEUCOSE
#  13            -    72    74    44   151  ...    HUMAINS^NEUCOSE
#  14            -   256   256   208     1  ...    HUMAINS^NEUCOSE
#  15            -   256   256   208     1  ...    HUMAINS^NEUCOSE
#  16            -    72    74    44   235  ...    HUMAINS^NEUCOSE
#  17            -    72    74    44   151  ...    HUMAINS^NEUCOSE
#
#      referring_physician_name          series_description  sequence_name  \
#  0                        NaN                   AUTOALIGN      *fl3d1_ns
#  1                        NaN           AUTOALIGN_MPR_sag      *fl3d1_ns
#  2                        NaN           AUTOALIGN_MPR_cor      *fl3d1_ns
#  3                        NaN           AUTOALIGN_MPR_tra      *fl3d1_ns
#  4                        NaN            LOCA_T1_FL2D_SAG         *fl2d1
#  5                        NaN           RUNx_QC_tilt25_AP    epfid2d1_72
#  6                        NaN  RUNx_rs_3mmiso_TR2.4_44cpe    epfid2d1_72
#  7                        NaN  RUNx_er_3mmiso_TR2.4_44cpe    epfid2d1_72
#  8                        NaN            anat_t2star_2iso        *fl2d5r
#  9                        NaN            anat_t2star_2iso        *fl2d5r
#  10                       NaN            anat_3DT2_0.9iso     *spc_314ns
#  11                       NaN            anat_3DT2_0.9iso     *spc_314ns
#  12                       NaN  RUNx_rs_3mmiso_TR2.4_44cpe    epfid2d1_72
#  13                       NaN  RUNx_er_3mmiso_TR2.4_44cpe    epfid2d1_72
#  14                       NaN            anat_3DT1_0.9iso   *tfl3d1_16ns
#  15                       NaN            anat_3DT1_0.9iso   *tfl3d1_16ns
#  16                       NaN  RUNx_rs_3mmiso_TR2.4_44cpe    epfid2d1_72
#  17                       NaN  RUNx_er_3mmiso_TR2.4_44cpe    epfid2d1_72
#
#                                             image_type accession_number  \
#  0          ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM')       BUEAL07925
#  1        ('ORIGINAL', 'PRIMARY', 'MPR', 'ND', 'NORM')       BUEAL07925
#  2        ('ORIGINAL', 'PRIMARY', 'MPR', 'ND', 'NORM')       BUEAL07925
#  3        ('ORIGINAL', 'PRIMARY', 'MPR', 'ND', 'NORM')       BUEAL07925
#  4          ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM')       BUEAL07925
#  5   ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM', 'MO...       BUEAL07925
#  6   ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM', 'MO...       BUEAL07925
#  7   ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM', 'MO...       BUEAL07925
#  8          ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM')       BUEAL07925
#  9                  ('ORIGINAL', 'PRIMARY', 'P', 'ND')       BUEAL07925
#  10                 ('ORIGINAL', 'PRIMARY', 'M', 'ND')       BUEAL07925
#  11         ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM')       BUEAL07925
#  12  ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM', 'MO...       BUEAL07925
#  13  ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM', 'MO...       BUEAL07925
#  14                 ('ORIGINAL', 'PRIMARY', 'M', 'ND')       BUEAL07925
#  15         ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM')       BUEAL07925
#  16  ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM', 'MO...       BUEAL07925
#  17  ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM', 'MO...       BUEAL07925
#
#     patient_age  patient_sex      date  \
#  0         022Y            M  20180720
#  1         022Y            M  20180720
#  2         022Y            M  20180720
#  3         022Y            M  20180720
#  4         022Y            M  20180720
#  5         022Y            M  20180720
#  6         022Y            M  20180720
#  7         022Y            M  20180720
#  8         022Y            M  20180720
#  9         022Y            M  20180720
#  10        022Y            M  20180720
#  11        022Y            M  20180720
#  12        022Y            M  20180720
#  13        022Y            M  20180720
#  14        022Y            M  20180720
#  15        022Y            M  20180720
#  16        022Y            M  20180720
#  17        022Y            M  20180720
#
#                                             series_uid
#  0   1.3.12.2.1107.5.2.43.66012.2018072009281047496...
#  1   1.3.12.2.1107.5.2.43.66012.2018072009281626906...
#  2   1.3.12.2.1107.5.2.43.66012.2018072009281626955...
#  3   1.3.12.2.1107.5.2.43.66012.2018072009281626984...
#  4   1.3.12.2.1107.5.2.43.66012.2018072009284657096...
#  5   1.3.12.2.1107.5.2.43.66012.2018072009310276255...
#  6   1.3.12.2.1107.5.2.43.66012.2018072009340315986...
#  7   1.3.12.2.1107.5.2.43.66012.2018072009434119954...
#  8   1.3.12.2.1107.5.2.43.66012.2018072009543853380...
#  9   1.3.12.2.1107.5.2.43.66012.2018072009543853381...
#  10  1.3.12.2.1107.5.2.43.66012.2018072010023662886...
#  11  1.3.12.2.1107.5.2.43.66012.2018072010023673944...
#  12  1.3.12.2.1107.5.2.43.66012.2018072010025610559...
#  13  1.3.12.2.1107.5.2.43.66012.2018072010124679320...
#  14  1.3.12.2.1107.5.2.43.66012.2018072010292170915...
#  15  1.3.12.2.1107.5.2.43.66012.2018072010221329175...
#  16  1.3.12.2.1107.5.2.43.66012.2018072010292881379...
#  17  1.3.12.2.1107.5.2.43.66012.2018072010395255058...
#
#  [18 rows x 26 columns],
#  'Sub-5':     total_files_till_now                                   example_dcm_file  \
#  0                    128  1.3.12.2.1107.5.2.43.66012.3000001808210749349...
#  1                    133  1.3.12.2.1107.5.2.43.66012.3000001808210749349...
#  2                    136  1.3.12.2.1107.5.2.43.66012.3000001808210749349...
#  3                    139  1.3.12.2.1107.5.2.43.66012.3000001808210749349...
#  4                    168  1.3.12.2.1107.5.2.43.66012.3000001808210749349...
#  5                    197  1.3.12.2.1107.5.2.43.66012.3000001808210749349...
#  6                    325  1.3.12.2.1107.5.2.43.66012.3000001808210749349...
#  7                    330  1.3.12.2.1107.5.2.43.66012.3000001808210749349...
#  8                    333  1.3.12.2.1107.5.2.43.66012.3000001808210749349...
#  9                    336  1.3.12.2.1107.5.2.43.66012.3000001808210749349...
#  10                   365  1.3.12.2.1107.5.2.43.66012.3000001808210749349...
#  11                   366  1.3.12.2.1107.5.2.43.66012.3000001808210749349...
#  12                   601  1.3.12.2.1107.5.2.43.66012.3000001808210749349...
#  13                   749  1.3.12.2.1107.5.2.43.66012.3000001808210749349...
#  14                  1149  1.3.12.2.1107.5.2.43.66012.3000001808210749349...
#  15                  1549  1.3.12.2.1107.5.2.43.66012.3000001808210749349...
#  16                  1757  1.3.12.2.1107.5.2.43.66012.3000001808210749349...
#  17                  1965  1.3.12.2.1107.5.2.43.66012.3000001808210749349...
#  18                  2200  1.3.12.2.1107.5.2.43.66012.3000001808210749349...
#  19                  2350  1.3.12.2.1107.5.2.43.66012.3000001808210749349...
#  20                  2558  1.3.12.2.1107.5.2.43.66012.3000001808210749349...
#  21                  2766  1.3.12.2.1107.5.2.43.66012.3000001808210749349...
#  22                  3001  1.3.12.2.1107.5.2.43.66012.3000001808210749349...
#  23                  3152  1.3.12.2.1107.5.2.43.66012.3000001808210749349...
#
#                          series_id                   dcm_dir_name unspecified2  \
#  0                     1-AUTOALIGN                    1_AUTOALIGN            -
#  1                     2-AUTOALIGN            2_AUTOALIGN_MPR_sag            -
#  2                     3-AUTOALIGN            3_AUTOALIGN_MPR_cor            -
#  3                     4-AUTOALIGN            4_AUTOALIGN_MPR_tra            -
#  4              5-LOCA_T1_FL2D_SAG             5_LOCA_T1_FL2D_SAG            -
#  5              6-LOCA_T1_FL2D_SAG             6_LOCA_T1_FL2D_SAG            -
#  6                     7-AUTOALIGN                    7_AUTOALIGN            -
#  7                     8-AUTOALIGN            8_AUTOALIGN_MPR_sag            -
#  8                     9-AUTOALIGN            9_AUTOALIGN_MPR_cor            -
#  9                    10-AUTOALIGN           10_AUTOALIGN_MPR_tra            -
#  10            11-LOCA_T1_FL2D_SAG            11_LOCA_T1_FL2D_SAG            -
#  11           12-RUNx_QC_tilt25_AP           12_RUNx_QC_tilt25_AP            -
#  12  14-RUNx_rs_3mmiso_TR2.4_44cpe  14_RUNx_rs_3mmiso_TR2.4_44cpe            -
#  13  16-RUNx_er_3mmiso_TR2.4_44cpe  16_RUNx_er_3mmiso_TR2.4_44cpe            -
#  14            18-anat_t2star_2iso            18_anat_t2star_2iso            -
#  15            19-anat_t2star_2iso            19_anat_t2star_2iso            -
#  16            20-anat_3DT2_0.9iso            20_anat_3DT2_0.9iso            -
#  17            21-anat_3DT2_0.9iso            21_anat_3DT2_0.9iso            -
#  18  22-RUNx_rs_3mmiso_TR2.4_44cpe  22_RUNx_rs_3mmiso_TR2.4_44cpe            -
#  19  24-RUNx_er_3mmiso_TR2.4_44cpe  24_RUNx_er_3mmiso_TR2.4_44cpe            -
#  20            26-anat_3DT1_0.9iso            26_anat_3DT1_0.9iso            -
#  21            27-anat_3DT1_0.9iso            27_anat_3DT1_0.9iso            -
#  22  28-RUNx_rs_3mmiso_TR2.4_44cpe  28_RUNx_rs_3mmiso_TR2.4_44cpe            -
#  23  30-RUNx_er_3mmiso_TR2.4_44cpe  30_RUNx_er_3mmiso_TR2.4_44cpe            -
#
#     unspecified3  dim1  dim2  dim3  dim4  ...  study_description  \
#  0             -   160   160   128     1  ...    HUMAINS^NEUCOSE
#  1             -   162   162     5     1  ...    HUMAINS^NEUCOSE
#  2             -   162   162     3     1  ...    HUMAINS^NEUCOSE
#  3             -   162   162     3     1  ...    HUMAINS^NEUCOSE
#  4             -   192   192    29     1  ...    HUMAINS^NEUCOSE
#  5             -   192   192    29     1  ...    HUMAINS^NEUCOSE
#  6             -   160   160   128     1  ...    HUMAINS^NEUCOSE
#  7             -   162   162     5     1  ...    HUMAINS^NEUCOSE
#  8             -   162   162     3     1  ...    HUMAINS^NEUCOSE
#  9             -   162   162     3     1  ...    HUMAINS^NEUCOSE
#  10            -   192   192    29     1  ...    HUMAINS^NEUCOSE
#  11            -    72    74    44     1  ...    HUMAINS^NEUCOSE
#  12            -    72    74    44   235  ...    HUMAINS^NEUCOSE
#  13            -    72    74    44   148  ...    HUMAINS^NEUCOSE
#  14            -   108   128   400     1  ...    HUMAINS^NEUCOSE
#  15            -   108   128   400     1  ...    HUMAINS^NEUCOSE
#  16            -   256   256   208     1  ...    HUMAINS^NEUCOSE
#  17            -   256   256   208     1  ...    HUMAINS^NEUCOSE
#  18            -    72    74    44   235  ...    HUMAINS^NEUCOSE
#  19            -    72    74    44   150  ...    HUMAINS^NEUCOSE
#  20            -   256   256   208     1  ...    HUMAINS^NEUCOSE
#  21            -   256   256   208     1  ...    HUMAINS^NEUCOSE
#  22            -    72    74    44   235  ...    HUMAINS^NEUCOSE
#  23            -    72    74    44   151  ...    HUMAINS^NEUCOSE
#
#      referring_physician_name          series_description  sequence_name  \
#  0                        NaN                   AUTOALIGN      *fl3d1_ns
#  1                        NaN           AUTOALIGN_MPR_sag      *fl3d1_ns
#  2                        NaN           AUTOALIGN_MPR_cor      *fl3d1_ns
#  3                        NaN           AUTOALIGN_MPR_tra      *fl3d1_ns
#  4                        NaN            LOCA_T1_FL2D_SAG         *fl2d1
#  5                        NaN            LOCA_T1_FL2D_SAG         *fl2d1
#  6                        NaN                   AUTOALIGN      *fl3d1_ns
#  7                        NaN           AUTOALIGN_MPR_sag      *fl3d1_ns
#  8                        NaN           AUTOALIGN_MPR_cor      *fl3d1_ns
#  9                        NaN           AUTOALIGN_MPR_tra      *fl3d1_ns
#  10                       NaN            LOCA_T1_FL2D_SAG         *fl2d1
#  11                       NaN           RUNx_QC_tilt25_AP    epfid2d1_72
#  12                       NaN  RUNx_rs_3mmiso_TR2.4_44cpe    epfid2d1_72
#  13                       NaN  RUNx_er_3mmiso_TR2.4_44cpe    epfid2d1_72
#  14                       NaN            anat_t2star_2iso        *fl2d5r
#  15                       NaN            anat_t2star_2iso        *fl2d5r
#  16                       NaN            anat_3DT2_0.9iso     *spc_314ns
#  17                       NaN            anat_3DT2_0.9iso     *spc_314ns
#  18                       NaN  RUNx_rs_3mmiso_TR2.4_44cpe    epfid2d1_72
#  19                       NaN  RUNx_er_3mmiso_TR2.4_44cpe    epfid2d1_72
#  20                       NaN            anat_3DT1_0.9iso   *tfl3d1_16ns
#  21                       NaN            anat_3DT1_0.9iso   *tfl3d1_16ns
#  22                       NaN  RUNx_rs_3mmiso_TR2.4_44cpe    epfid2d1_72
#  23                       NaN  RUNx_er_3mmiso_TR2.4_44cpe    epfid2d1_72
#
#                                             image_type accession_number  \
#  0                  ('ORIGINAL', 'PRIMARY', 'M', 'ND')       BLUAL07960
#  1                 ('DERIVED', 'PRIMARY', 'MPR', 'ND')       BLUAL07960
#  2                 ('DERIVED', 'PRIMARY', 'MPR', 'ND')       BLUAL07960
#  3                 ('DERIVED', 'PRIMARY', 'MPR', 'ND')       BLUAL07960
#  4          ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM')       BLUAL07960
#  5          ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM')       BLUAL07960
#  6                  ('ORIGINAL', 'PRIMARY', 'M', 'ND')       BLUAL07960
#  7                 ('DERIVED', 'PRIMARY', 'MPR', 'ND')       BLUAL07960
#  8                 ('DERIVED', 'PRIMARY', 'MPR', 'ND')       BLUAL07960
#  9                 ('DERIVED', 'PRIMARY', 'MPR', 'ND')       BLUAL07960
#  10         ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM')       BLUAL07960
#  11  ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM', 'MO...       BLUAL07960
#  12  ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM', 'MO...       BLUAL07960
#  13  ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM', 'MO...       BLUAL07960
#  14         ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM')       BLUAL07960
#  15                 ('ORIGINAL', 'PRIMARY', 'P', 'ND')       BLUAL07960
#  16                 ('ORIGINAL', 'PRIMARY', 'M', 'ND')       BLUAL07960
#  17         ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM')       BLUAL07960
#  18  ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM', 'MO...       BLUAL07960
#  19  ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM', 'MO...       BLUAL07960
#  20                 ('ORIGINAL', 'PRIMARY', 'M', 'ND')       BLUAL07960
#  21         ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM')       BLUAL07960
#  22  ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM', 'MO...       BLUAL07960
#  23  ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM', 'MO...       BLUAL07960
#
#     patient_age  patient_sex      date  \
#  0         025Y            M  20180821
#  1         025Y            M  20180821
#  2         025Y            M  20180821
#  3         025Y            M  20180821
#  4         025Y            M  20180821
#  5         025Y            M  20180821
#  6         025Y            M  20180821
#  7         025Y            M  20180821
#  8         025Y            M  20180821
#  9         025Y            M  20180821
#  10        025Y            M  20180821
#  11        025Y            M  20180821
#  12        025Y            M  20180821
#  13        025Y            M  20180821
#  14        025Y            M  20180821
#  15        025Y            M  20180821
#  16        025Y            M  20180821
#  17        025Y            M  20180821
# ...
#  9             13-anat_3DT1_0.9iso            13_anat_3DT1_0.9iso            -
#  10  14-RUNx_rs_3mmiso_TR2.4_44cpe  14_RUNx_rs_3mmiso_TR2.4_44cpe            -
#  11  16-RUNx_er_3mmiso_TR2.4_44cpe  16_RUNx_er_3mmiso_TR2.4_44cpe            -
#  12            18-anat_t2star_2iso            18_anat_t2star_2iso            -
#  13            19-anat_t2star_2iso            19_anat_t2star_2iso            -
#  14            20-anat_3DT2_0.9iso            20_anat_3DT2_0.9iso            -
#  15            21-anat_3DT2_0.9iso            21_anat_3DT2_0.9iso            -
#  16  22-RUNx_rs_3mmiso_TR2.4_44cpe  22_RUNx_rs_3mmiso_TR2.4_44cpe            -
#  17  24-RUNx_er_3mmiso_TR2.4_44cpe  24_RUNx_er_3mmiso_TR2.4_44cpe            -
#
#     unspecified3  dim1  dim2  dim3  dim4  ...  study_description  \
#  0             -   160   160   128     1  ...    HUMAINS^NEUCOSE
#  1             -   162   162     5     1  ...    HUMAINS^NEUCOSE
#  2             -   162   162     3     1  ...    HUMAINS^NEUCOSE
#  3             -   162   162     3     1  ...    HUMAINS^NEUCOSE
#  4             -   192   192    29     1  ...    HUMAINS^NEUCOSE
#  5             -    72    74    44     1  ...    HUMAINS^NEUCOSE
#  6             -    72    74    44   235  ...    HUMAINS^NEUCOSE
#  7             -    72    74    44   152  ...    HUMAINS^NEUCOSE
#  8             -   256   256   208     1  ...    HUMAINS^NEUCOSE
#  9             -   256   256   208     1  ...    HUMAINS^NEUCOSE
#  10            -    72    74    44   235  ...    HUMAINS^NEUCOSE
#  11            -    72    74    44   152  ...    HUMAINS^NEUCOSE
#  12            -   108   128   400     1  ...    HUMAINS^NEUCOSE
#  13            -   108   128   400     1  ...    HUMAINS^NEUCOSE
#  14            -   256   256   208     1  ...    HUMAINS^NEUCOSE
#  15            -   256   256   208     1  ...    HUMAINS^NEUCOSE
#  16            -    72    74    44   235  ...    HUMAINS^NEUCOSE
#  17            -    72    74    44   155  ...    HUMAINS^NEUCOSE
#
#      referring_physician_name          series_description  sequence_name  \
#  0                        NaN                   AUTOALIGN      *fl3d1_ns
#  1                        NaN           AUTOALIGN_MPR_sag      *fl3d1_ns
#  2                        NaN           AUTOALIGN_MPR_cor      *fl3d1_ns
#  3                        NaN           AUTOALIGN_MPR_tra      *fl3d1_ns
#  4                        NaN            LOCA_T1_FL2D_SAG         *fl2d1
#  5                        NaN           RUNx_QC_tilt25_AP    epfid2d1_72
#  6                        NaN  RUNx_rs_3mmiso_TR2.4_44cpe    epfid2d1_72
#  7                        NaN  RUNx_er_3mmiso_TR2.4_44cpe    epfid2d1_72
#  8                        NaN            anat_3DT1_0.9iso   *tfl3d1_16ns
#  9                        NaN            anat_3DT1_0.9iso   *tfl3d1_16ns
#  10                       NaN  RUNx_rs_3mmiso_TR2.4_44cpe    epfid2d1_72
#  11                       NaN  RUNx_er_3mmiso_TR2.4_44cpe    epfid2d1_72
#  12                       NaN            anat_t2star_2iso        *fl2d5r
#  13                       NaN            anat_t2star_2iso        *fl2d5r
#  14                       NaN            anat_3DT2_0.9iso     *spc_314ns
#  15                       NaN            anat_3DT2_0.9iso     *spc_314ns
#  16                       NaN  RUNx_rs_3mmiso_TR2.4_44cpe    epfid2d1_72
#  17                       NaN  RUNx_er_3mmiso_TR2.4_44cpe    epfid2d1_72
#
#                                             image_type accession_number  \
#  0          ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM')       BUCRO07986
#  1         ('DERIVED', 'PRIMARY', 'MPR', 'ND', 'NORM')       BUCRO07986
#  2         ('DERIVED', 'PRIMARY', 'MPR', 'ND', 'NORM')       BUCRO07986
#  3         ('DERIVED', 'PRIMARY', 'MPR', 'ND', 'NORM')       BUCRO07986
#  4          ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM')       BUCRO07986
#  5   ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM', 'MO...       BUCRO07986
#  6   ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM', 'MO...       BUCRO07986
#  7   ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM', 'MO...       BUCRO07986
#  8                  ('ORIGINAL', 'PRIMARY', 'M', 'ND')       BUCRO07986
#  9          ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM')       BUCRO07986
#  10  ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM', 'MO...       BUCRO07986
#  11  ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM', 'MO...       BUCRO07986
#  12         ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM')       BUCRO07986
#  13                 ('ORIGINAL', 'PRIMARY', 'P', 'ND')       BUCRO07986
#  14                 ('ORIGINAL', 'PRIMARY', 'M', 'ND')       BUCRO07986
#  15         ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM')       BUCRO07986
#  16  ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM', 'MO...       BUCRO07986
#  17  ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM', 'MO...       BUCRO07986
#
#     patient_age  patient_sex      date  \
#  0         032Y            M  20180914
#  1         032Y            M  20180914
#  2         032Y            M  20180914
#  3         032Y            M  20180914
#  4         032Y            M  20180914
#  5         032Y            M  20180914
#  6         032Y            M  20180914
#  7         032Y            M  20180914
#  8         032Y            M  20180914
#  9         032Y            M  20180914
#  10        032Y            M  20180914
#  11        032Y            M  20180914
#  12        032Y            M  20180914
#  13        032Y            M  20180914
#  14        032Y            M  20180914
#  15        032Y            M  20180914
#  16        032Y            M  20180914
#  17        032Y            M  20180914
#
#                                             series_uid
#  0   1.3.12.2.1107.5.2.43.66012.2018091411050717933...
#  1   1.3.12.2.1107.5.2.43.66012.2018091411051132772...
#  2   1.3.12.2.1107.5.2.43.66012.2018091411051132815...
#  3   1.3.12.2.1107.5.2.43.66012.2018091411051132837...
#  4   1.3.12.2.1107.5.2.43.66012.2018091411082152071...
#  5   1.3.12.2.1107.5.2.43.66012.2018091411120423991...
#  6   1.3.12.2.1107.5.2.43.66012.2018091411143334628...
#  7   1.3.12.2.1107.5.2.43.66012.2018091411244664051...
#  8   1.3.12.2.1107.5.2.43.66012.2018091411423043897...
#  9   1.3.12.2.1107.5.2.43.66012.2018091411351632957...
#  10  1.3.12.2.1107.5.2.43.66012.2018091411424165253...
#  11  1.3.12.2.1107.5.2.43.66012.2018091411524271978...
#  12  1.3.12.2.1107.5.2.43.66012.2018091412030546893...
#  13  1.3.12.2.1107.5.2.43.66012.2018091412030546894...
#  14  1.3.12.2.1107.5.2.43.66012.2018091412105333397...
#  15  1.3.12.2.1107.5.2.43.66012.2018091412105337629...
#  16  1.3.12.2.1107.5.2.43.66012.2018091412110754124...
#  17  1.3.12.2.1107.5.2.43.66012.2018091412204495087...
#
#  [18 rows x 26 columns],
#  'Sub-40':     total_files_till_now                                   example_dcm_file  \
#  0                    128  1.3.12.2.1107.5.2.43.66012.3000001806040846088...
#  1                    133  1.3.12.2.1107.5.2.43.66012.3000001806040846088...
#  2                    136  1.3.12.2.1107.5.2.43.66012.3000001806040846088...
#  3                    139  1.3.12.2.1107.5.2.43.66012.3000001806040846088...
#  4                    159  1.3.12.2.1107.5.2.43.66012.3000001806040846088...
#  5                    160  1.3.12.2.1107.5.2.43.66012.3000001806040846088...
#  6                    395  1.3.12.2.1107.5.2.43.66012.3000001806040846088...
#  7                    543  1.3.12.2.1107.5.2.43.66012.3000001806040846088...
#  8                    943  1.3.12.2.1107.5.2.43.66012.3000001806040846088...
#  9                   1343  1.3.12.2.1107.5.2.43.66012.3000001806040846088...
#  10                  1551  1.3.12.2.1107.5.2.43.66012.3000001806040846088...
#  11                  1759  1.3.12.2.1107.5.2.43.66012.3000001806040846088...
#  12                  1994  1.3.12.2.1107.5.2.43.66012.3000001806040846088...
#  13                  2141  1.3.12.2.1107.5.2.43.66012.3000001806040846088...
#  14                  2349  1.3.12.2.1107.5.2.43.66012.3000001806040846088...
#  15                  2557  1.3.12.2.1107.5.2.43.66012.3000001806040846088...
#  16                  2792  1.3.12.2.1107.5.2.43.66012.3000001806040846088...
#  17                  2944  1.3.12.2.1107.5.2.43.66012.3000001806040846088...
#
#                          series_id                   dcm_dir_name unspecified2  \
#  0                     1-AUTOALIGN                    1_AUTOALIGN            -
#  1                     2-AUTOALIGN            2_AUTOALIGN_MPR_sag            -
#  2                     3-AUTOALIGN            3_AUTOALIGN_MPR_cor            -
#  3                     4-AUTOALIGN            4_AUTOALIGN_MPR_tra            -
#  4              5-LOCA_T1_FL2D_SAG             5_LOCA_T1_FL2D_SAG            -
#  5             7-RUNx_QC_tilt25_AP            7_RUNx_QC_tilt25_AP            -
#  6    8-RUNx_rs_3mmiso_TR2.4_44cpe   8_RUNx_rs_3mmiso_TR2.4_44cpe            -
#  7   10-RUNx_er_3mmiso_TR2.4_44cpe  10_RUNx_er_3mmiso_TR2.4_44cpe            -
#  8             12-anat_t2star_2iso            12_anat_t2star_2iso            -
#  9             13-anat_t2star_2iso            13_anat_t2star_2iso            -
#  10            14-anat_3DT2_0.9iso            14_anat_3DT2_0.9iso            -
#  11            15-anat_3DT2_0.9iso            15_anat_3DT2_0.9iso            -
#  12  16-RUNx_rs_3mmiso_TR2.4_44cpe  16_RUNx_rs_3mmiso_TR2.4_44cpe            -
#  13  18-RUNx_er_3mmiso_TR2.4_44cpe  18_RUNx_er_3mmiso_TR2.4_44cpe            -
#  14            20-anat_3DT1_0.9iso            20_anat_3DT1_0.9iso            -
#  15            21-anat_3DT1_0.9iso            21_anat_3DT1_0.9iso            -
#  16  22-RUNx_rs_3mmiso_TR2.4_44cpe  22_RUNx_rs_3mmiso_TR2.4_44cpe            -
#  17  24-RUNx_er_3mmiso_TR2.4_44cpe  24_RUNx_er_3mmiso_TR2.4_44cpe            -
#
#     unspecified3  dim1  dim2  dim3  dim4  ...  study_description  \
#  0             -   160   160   128     1  ...    HUMAINS^NEUCOSE
#  1             -   162   162     5     1  ...    HUMAINS^NEUCOSE
#  2             -   162   162     3     1  ...    HUMAINS^NEUCOSE
#  3             -   162   162     3     1  ...    HUMAINS^NEUCOSE
#  4             -   192   192    20     1  ...    HUMAINS^NEUCOSE
#  5             -    72    74    44     1  ...    HUMAINS^NEUCOSE
#  6             -    72    74    44   235  ...    HUMAINS^NEUCOSE
#  7             -    72    74    44   148  ...    HUMAINS^NEUCOSE
#  8             -   108   128   400     1  ...    HUMAINS^NEUCOSE
#  9             -   108   128   400     1  ...    HUMAINS^NEUCOSE
#  10            -   256   256   208     1  ...    HUMAINS^NEUCOSE
#  11            -   256   256   208     1  ...    HUMAINS^NEUCOSE
#  12            -    72    74    44   235  ...    HUMAINS^NEUCOSE
#  13            -    72    74    44   147  ...    HUMAINS^NEUCOSE
#  14            -   256   256   208     1  ...    HUMAINS^NEUCOSE
#  15            -   256   256   208     1  ...    HUMAINS^NEUCOSE
#  16            -    72    74    44   235  ...    HUMAINS^NEUCOSE
#  17            -    72    74    44   152  ...    HUMAINS^NEUCOSE
#
#      referring_physician_name          series_description  sequence_name  \
#  0                        NaN                   AUTOALIGN      *fl3d1_ns
#  1                        NaN           AUTOALIGN_MPR_sag      *fl3d1_ns
#  2                        NaN           AUTOALIGN_MPR_cor      *fl3d1_ns
#  3                        NaN           AUTOALIGN_MPR_tra      *fl3d1_ns
#  4                        NaN            LOCA_T1_FL2D_SAG         *fl2d1
#  5                        NaN           RUNx_QC_tilt25_AP    epfid2d1_72
#  6                        NaN  RUNx_rs_3mmiso_TR2.4_44cpe    epfid2d1_72
#  7                        NaN  RUNx_er_3mmiso_TR2.4_44cpe    epfid2d1_72
#  8                        NaN            anat_t2star_2iso        *fl2d5r
#  9                        NaN            anat_t2star_2iso        *fl2d5r
#  10                       NaN            anat_3DT2_0.9iso     *spc_314ns
#  11                       NaN            anat_3DT2_0.9iso     *spc_314ns
#  12                       NaN  RUNx_rs_3mmiso_TR2.4_44cpe    epfid2d1_72
#  13                       NaN  RUNx_er_3mmiso_TR2.4_44cpe    epfid2d1_72
#  14                       NaN            anat_3DT1_0.9iso   *tfl3d1_16ns
#  15                       NaN            anat_3DT1_0.9iso   *tfl3d1_16ns
#  16                       NaN  RUNx_rs_3mmiso_TR2.4_44cpe    epfid2d1_72
#  17                       NaN  RUNx_er_3mmiso_TR2.4_44cpe    epfid2d1_72
#
#                                             image_type accession_number  \
#  0          ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM')       VASAU07841
#  1        ('ORIGINAL', 'PRIMARY', 'MPR', 'ND', 'NORM')       VASAU07841
#  2        ('ORIGINAL', 'PRIMARY', 'MPR', 'ND', 'NORM')       VASAU07841
#  3        ('ORIGINAL', 'PRIMARY', 'MPR', 'ND', 'NORM')       VASAU07841
#  4          ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM')       VASAU07841
#  5   ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM', 'MO...       VASAU07841
#  6   ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM', 'MO...       VASAU07841
#  7   ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM', 'MO...       VASAU07841
#  8          ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM')       VASAU07841
#  9                  ('ORIGINAL', 'PRIMARY', 'P', 'ND')       VASAU07841
#  10                 ('ORIGINAL', 'PRIMARY', 'M', 'ND')       VASAU07841
#  11         ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM')       VASAU07841
#  12  ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM', 'MO...       VASAU07841
#  13  ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM', 'MO...       VASAU07841
#  14                 ('ORIGINAL', 'PRIMARY', 'M', 'ND')       VASAU07841
#  15         ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM')       VASAU07841
#  16  ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM', 'MO...       VASAU07841
#  17  ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM', 'MO...       VASAU07841
#
#     patient_age  patient_sex      date  \
#  0         022Y            F  20180604
#  1         022Y            F  20180604
#  2         022Y            F  20180604
#  3         022Y            F  20180604
#  4         022Y            F  20180604
#  5         022Y            F  20180604
#  6         022Y            F  20180604
#  7         022Y            F  20180604
#  8         022Y            F  20180604
#  9         022Y            F  20180604
#  10        022Y            F  20180604
#  11        022Y            F  20180604
#  12        022Y            F  20180604
#  13        022Y            F  20180604
#  14        022Y            F  20180604
#  15        022Y            F  20180604
#  16        022Y            F  20180604
#  17        022Y            F  20180604
#
#                                             series_uid
#  0   1.3.12.2.1107.5.2.43.66012.2018060409473764457...
#  1   1.3.12.2.1107.5.2.43.66012.2018060409474266197...
#  2   1.3.12.2.1107.5.2.43.66012.2018060409474266248...
#  3   1.3.12.2.1107.5.2.43.66012.2018060409474266277...
#  4   1.3.12.2.1107.5.2.43.66012.2018060409483354124...
#  5   1.3.12.2.1107.5.2.43.66012.2018060409513992025...
#  6   1.3.12.2.1107.5.2.43.66012.2018060409521573050...
#  7   1.3.12.2.1107.5.2.43.66012.2018060410031028361...
#  8   1.3.12.2.1107.5.2.43.66012.2018060410124518624...
#  9   1.3.12.2.1107.5.2.43.66012.2018060410124518625...
#  10  1.3.12.2.1107.5.2.43.66012.2018060410203249162...
#  11  1.3.12.2.1107.5.2.43.66012.2018060410203254135...
#  12  1.3.12.2.1107.5.2.43.66012.2018060410204187441...
#  13  1.3.12.2.1107.5.2.43.66012.2018060410303034418...
#  14  1.3.12.2.1107.5.2.43.66012.2018060410463970054...
#  15  1.3.12.2.1107.5.2.43.66012.2018060410393088768...
#  16  1.3.12.2.1107.5.2.43.66012.2018060410464649951...
#  17  1.3.12.2.1107.5.2.43.66012.2018060410563925072...
#
#  [18 rows x 26 columns]}

# %%
select_subjects = [1,2] #None to run all, or ids of the subjetcs for whom we want to get the infos
select_subjects = None
if select_subjects:
    bids_info_paths_selected = list()
    bids_info_paths_selected.extend([path for (_,path) in enumerate(bids_info_paths,1) if _ in select_subjects]) 
    print('Selected files : ',bids_info_paths_selected)
    dcm_df,infos_dict_indxs,dcm_dict_paths = get_dicom_infos(bids_info_paths=bids_info_paths_selected,print_paths=False)
else:
    select_subjects = list(np.arange(1,40))
    dcm_df,infos_dict_indxs,dcm_dict_paths = get_dicom_infos(bids_info_paths,print_paths=False)
    
indx = 1

for indx in (infos_dict_indxs):
    print(indx)
    #print(infos_dict_indxs['Sub-{}'.format(indx)])
    print(infos_dict_indxs[indx].series_id)
# Out:
# Sub-1
# 0                       1-AUTOALIGN
# 1                       2-AUTOALIGN
# 2                       3-AUTOALIGN
# 3                       4-AUTOALIGN
# 4                5-LOCA_T1_FL2D_SAG
# 5               7-RUNx_QC_tilt25_AP
# 6      8-RUNx_rs_3mmiso_TR2.4_44cpe
# 7     10-RUNx_er_3mmiso_TR2.4_44cpe
# 8               12-anat_t2star_2iso
# 9               13-anat_t2star_2iso
# 10              14-anat_3DT2_0.9iso
# 11              15-anat_3DT2_0.9iso
# 12    16-RUNx_rs_3mmiso_TR2.4_44cpe
# 13    18-RUNx_er_3mmiso_TR2.4_44cpe
# 14              20-anat_3DT1_0.9iso
# 15              21-anat_3DT1_0.9iso
# 16    22-RUNx_rs_3mmiso_TR2.4_44cpe
# 17    24-RUNx_er_3mmiso_TR2.4_44cpe
# 18              26-anat_3DT1_0.9iso
# 19              27-anat_3DT1_0.9iso
# Name: series_id, dtype: object
# Sub-2
# 0                       1-AUTOALIGN
# 1                       2-AUTOALIGN
# 2                       3-AUTOALIGN
# 3                       4-AUTOALIGN
# 4                5-LOCA_T1_FL2D_SAG
# 5               7-RUNx_QC_tilt25_AP
# 6      8-RUNx_rs_3mmiso_TR2.4_44cpe
# 7     10-RUNx_er_3mmiso_TR2.4_44cpe
# 8               12-anat_t2star_2iso
# 9               13-anat_t2star_2iso
# 10              14-anat_3DT2_0.9iso
# 11              15-anat_3DT2_0.9iso
# 12    16-RUNx_rs_3mmiso_TR2.4_44cpe
# 13    18-RUNx_er_3mmiso_TR2.4_44cpe
# 14              20-anat_3DT1_0.9iso
# 15              21-anat_3DT1_0.9iso
# 16    22-RUNx_rs_3mmiso_TR2.4_44cpe
# 17    24-RUNx_er_3mmiso_TR2.4_44cpe
# Name: series_id, dtype: object
# Sub-3
# 0                       1-AUTOALIGN
# 1                       2-AUTOALIGN
# 2                       3-AUTOALIGN
# 3                       4-AUTOALIGN
# 4                5-LOCA_T1_FL2D_SAG
# 5               7-RUNx_QC_tilt25_AP
# 6      8-RUNx_rs_3mmiso_TR2.4_44cpe
# 7     10-RUNx_er_3mmiso_TR2.4_44cpe
# 8               12-anat_t2star_2iso
# 9               13-anat_t2star_2iso
# 10              14-anat_3DT2_0.9iso
# 11              15-anat_3DT2_0.9iso
# 12    16-RUNx_rs_3mmiso_TR2.4_44cpe
# 13    18-RUNx_er_3mmiso_TR2.4_44cpe
# 14              20-anat_3DT1_0.9iso
# 15              21-anat_3DT1_0.9iso
# 16    22-RUNx_rs_3mmiso_TR2.4_44cpe
# 17    24-RUNx_er_3mmiso_TR2.4_44cpe
# Name: series_id, dtype: object
# Sub-4
# 0                       1-AUTOALIGN
# 1                       2-AUTOALIGN
# 2                       3-AUTOALIGN
# 3                       4-AUTOALIGN
# 4                5-LOCA_T1_FL2D_SAG
# 5               7-RUNx_QC_tilt25_AP
# 6      8-RUNx_rs_3mmiso_TR2.4_44cpe
# 7     10-RUNx_er_3mmiso_TR2.4_44cpe
# 8               12-anat_t2star_2iso
# 9               13-anat_t2star_2iso
# 10              14-anat_3DT2_0.9iso
# 11              15-anat_3DT2_0.9iso
# 12    16-RUNx_rs_3mmiso_TR2.4_44cpe
# 13    18-RUNx_er_3mmiso_TR2.4_44cpe
# 14              20-anat_3DT1_0.9iso
# 15              21-anat_3DT1_0.9iso
# 16    22-RUNx_rs_3mmiso_TR2.4_44cpe
# 17    24-RUNx_er_3mmiso_TR2.4_44cpe
# Name: series_id, dtype: object
# Sub-5
# 0                       1-AUTOALIGN
# 1                       2-AUTOALIGN
# 2                       3-AUTOALIGN
# 3                       4-AUTOALIGN
# 4                5-LOCA_T1_FL2D_SAG
# 5                6-LOCA_T1_FL2D_SAG
# 6                       7-AUTOALIGN
# 7                       8-AUTOALIGN
# 8                       9-AUTOALIGN
# 9                      10-AUTOALIGN
# 10              11-LOCA_T1_FL2D_SAG
# 11             12-RUNx_QC_tilt25_AP
# 12    14-RUNx_rs_3mmiso_TR2.4_44cpe
# 13    16-RUNx_er_3mmiso_TR2.4_44cpe
# 14              18-anat_t2star_2iso
# 15              19-anat_t2star_2iso
# 16              20-anat_3DT2_0.9iso
# 17              21-anat_3DT2_0.9iso
# 18    22-RUNx_rs_3mmiso_TR2.4_44cpe
# 19    24-RUNx_er_3mmiso_TR2.4_44cpe
# 20              26-anat_3DT1_0.9iso
# 21              27-anat_3DT1_0.9iso
# 22    28-RUNx_rs_3mmiso_TR2.4_44cpe
# 23    30-RUNx_er_3mmiso_TR2.4_44cpe
# Name: series_id, dtype: object
# Sub-6
# 0                       1-AUTOALIGN
# 1                       2-AUTOALIGN
# 2                       3-AUTOALIGN
# 3                       4-AUTOALIGN
# 4                5-LOCA_T1_FL2D_SAG
# 5               7-RUNx_QC_tilt25_AP
# 6      8-RUNx_rs_3mmiso_TR2.4_44cpe
# 7     10-RUNx_er_3mmiso_TR2.4_44cpe
# 8               12-anat_t2star_2iso
# 9               13-anat_t2star_2iso
# 10              14-anat_3DT2_0.9iso
# 11              15-anat_3DT2_0.9iso
# 12    16-RUNx_rs_3mmiso_TR2.4_44cpe
# 13    18-RUNx_er_3mmiso_TR2.4_44cpe
# 14              20-anat_3DT1_0.9iso
# 15              21-anat_3DT1_0.9iso
# 16    22-RUNx_rs_3mmiso_TR2.4_44cpe
# 17    24-RUNx_er_3mmiso_TR2.4_44cpe
# Name: series_id, dtype: object
# Sub-7
# 0                       1-AUTOALIGN
# 1                       2-AUTOALIGN
# 2                       3-AUTOALIGN
# 3                       4-AUTOALIGN
# 4                5-LOCA_T1_FL2D_SAG
# 5               6-RUNx_QC_tilt25_AP
# 6                       8-AUTOALIGN
# 7                       9-AUTOALIGN
# 8                      10-AUTOALIGN
# 9                      11-AUTOALIGN
# 10              12-LOCA_T1_FL2D_SAG
# 11             13-RUNx_QC_tilt25_AP
# 12    15-RUNx_rs_3mmiso_TR2.4_44cpe
# 13    17-RUNx_er_3mmiso_TR2.4_44cpe
# 14              19-anat_3DT1_0.9iso
# 15              20-anat_3DT1_0.9iso
# 16    21-RUNx_rs_3mmiso_TR2.4_44cpe
# 17    23-RUNx_er_3mmiso_TR2.4_44cpe
# 18              25-anat_t2star_2iso
# 19              26-anat_t2star_2iso
# 20              27-anat_3DT2_0.9iso
# 21              28-anat_3DT2_0.9iso
# 22    29-RUNx_rs_3mmiso_TR2.4_44cpe
# 23    31-RUNx_er_3mmiso_TR2.4_44cpe
# Name: series_id, dtype: object
# Sub-8
# 0                       1-AUTOALIGN
# 1                       2-AUTOALIGN
# 2                       3-AUTOALIGN
# 3                       4-AUTOALIGN
# 4                5-LOCA_T1_FL2D_SAG
# 5               6-RUNx_QC_tilt25_AP
# 6      8-RUNx_rs_3mmiso_TR2.4_44cpe
# 7     10-RUNx_er_3mmiso_TR2.4_44cpe
# 8               12-anat_3DT1_0.9iso
# 9               13-anat_3DT1_0.9iso
# 10    14-RUNx_rs_3mmiso_TR2.4_44cpe
# 11    16-RUNx_er_3mmiso_TR2.4_44cpe
# 12              18-anat_t2star_2iso
# 13              19-anat_t2star_2iso
# 14              20-anat_3DT2_0.9iso
# 15              21-anat_3DT2_0.9iso
# 16    22-RUNx_rs_3mmiso_TR2.4_44cpe
# 17    24-RUNx_er_3mmiso_TR2.4_44cpe
# Name: series_id, dtype: object
# Sub-9
# 0                       1-AUTOALIGN
# 1                       2-AUTOALIGN
# 2                       3-AUTOALIGN
# 3                       4-AUTOALIGN
# 4                5-LOCA_T1_FL2D_SAG
# 5               7-RUNx_QC_tilt25_AP
# 6      8-RUNx_rs_3mmiso_TR2.4_44cpe
# 7     10-RUNx_er_3mmiso_TR2.4_44cpe
# 8               12-anat_t2star_2iso
# 9               13-anat_t2star_2iso
# 10              14-anat_3DT2_0.9iso
# 11              15-anat_3DT2_0.9iso
# 12    16-RUNx_rs_3mmiso_TR2.4_44cpe
# 13    18-RUNx_er_3mmiso_TR2.4_44cpe
# 14              20-anat_3DT1_0.9iso
# 15              21-anat_3DT1_0.9iso
# 16    22-RUNx_rs_3mmiso_TR2.4_44cpe
# 17    24-RUNx_er_3mmiso_TR2.4_44cpe
# Name: series_id, dtype: object
# Sub-10
# 0                       1-AUTOALIGN
# 1                       2-AUTOALIGN
# 2                       3-AUTOALIGN
# 3                       4-AUTOALIGN
# 4                5-LOCA_T1_FL2D_SAG
# 5               7-RUNx_QC_tilt25_AP
# 6      8-RUNx_rs_3mmiso_TR2.4_44cpe
# 7     10-RUNx_er_3mmiso_TR2.4_44cpe
# 8               12-anat_t2star_2iso
# 9               13-anat_t2star_2iso
# 10              14-anat_3DT2_0.9iso
# 11              15-anat_3DT2_0.9iso
# 12    16-RUNx_rs_3mmiso_TR2.4_44cpe
# 13    18-RUNx_er_3mmiso_TR2.4_44cpe
# 14              20-anat_3DT1_0.9iso
# 15              21-anat_3DT1_0.9iso
# 16    22-RUNx_rs_3mmiso_TR2.4_44cpe
# 17    25-RUNx_er_3mmiso_TR2.4_44cpe
# Name: series_id, dtype: object
# Sub-11
# 0                       1-AUTOALIGN
# 1                       2-AUTOALIGN
# 2                       3-AUTOALIGN
# 3                       4-AUTOALIGN
# 4                5-LOCA_T1_FL2D_SAG
# 5               6-RUNx_QC_tilt25_AP
# 6      8-RUNx_rs_3mmiso_TR2.4_44cpe
# 7     10-RUNx_er_3mmiso_TR2.4_44cpe
# 8               12-anat_3DT1_0.9iso
# 9               13-anat_3DT1_0.9iso
# 10    14-RUNx_rs_3mmiso_TR2.4_44cpe
# 11    16-RUNx_er_3mmiso_TR2.4_44cpe
# 12              18-anat_t2star_2iso
# 13              19-anat_t2star_2iso
# 14              20-anat_3DT2_0.9iso
# 15              21-anat_3DT2_0.9iso
# 16    22-RUNx_rs_3mmiso_TR2.4_44cpe
# 17    24-RUNx_er_3mmiso_TR2.4_44cpe
# Name: series_id, dtype: object
# Sub-12
# 0                       1-AUTOALIGN
# 1                       2-AUTOALIGN
# 2                       3-AUTOALIGN
# 3                       4-AUTOALIGN
# 4                5-LOCA_T1_FL2D_SAG
# 5               6-RUNx_QC_tilt25_AP
# 6      8-RUNx_rs_3mmiso_TR2.4_44cpe
# 7     10-RUNx_er_3mmiso_TR2.4_44cpe
# 8               12-anat_t2star_2iso
# 9               13-anat_t2star_2iso
# 10              14-anat_3DT2_0.9iso
# 11              15-anat_3DT2_0.9iso
# 12    16-RUNx_rs_3mmiso_TR2.4_44cpe
# 13    18-RUNx_er_3mmiso_TR2.4_44cpe
# 14                     20-AUTOALIGN
# 15                     21-AUTOALIGN
# 16                     22-AUTOALIGN
# 17                     23-AUTOALIGN
# 18              24-LOCA_T1_FL2D_SAG
# 19             25-RUNx_QC_tilt25_AP
# 20              27-anat_3DT1_0.9iso
# 21              28-anat_3DT1_0.9iso
# 22    29-RUNx_rs_3mmiso_TR2.4_44cpe
# 23    31-RUNx_er_3mmiso_TR2.4_44cpe
# Name: series_id, dtype: object
# Sub-13
# 0                       1-AUTOALIGN
# 1                       2-AUTOALIGN
# 2                       3-AUTOALIGN
# 3                       4-AUTOALIGN
# 4                5-LOCA_T1_FL2D_SAG
# 5               7-RUNx_QC_tilt25_AP
# 6      8-RUNx_rs_3mmiso_TR2.4_44cpe
# 7     10-RUNx_er_3mmiso_TR2.4_44cpe
# 8               12-anat_t2star_2iso
# 9               13-anat_t2star_2iso
# 10              14-anat_3DT2_0.9iso
# 11              15-anat_3DT2_0.9iso
# 12    16-RUNx_rs_3mmiso_TR2.4_44cpe
# 13    18-RUNx_er_3mmiso_TR2.4_44cpe
# 14              20-anat_3DT1_0.9iso
# 15              21-anat_3DT1_0.9iso
# 16    22-RUNx_rs_3mmiso_TR2.4_44cpe
# 17    24-RUNx_er_3mmiso_TR2.4_44cpe
# Name: series_id, dtype: object
# Sub-14
# 0                       1-AUTOALIGN
# 1                       2-AUTOALIGN
# 2                       3-AUTOALIGN
# 3                       4-AUTOALIGN
# 4                5-LOCA_T1_FL2D_SAG
# 5               6-RUNx_QC_tilt25_AP
# 6      8-RUNx_rs_3mmiso_TR2.4_44cpe
# 7     10-RUNx_er_3mmiso_TR2.4_44cpe
# 8               12-anat_3DT1_0.9iso
# 9               13-anat_3DT1_0.9iso
# 10    14-RUNx_rs_3mmiso_TR2.4_44cpe
# 11    16-RUNx_er_3mmiso_TR2.4_44cpe
# 12              18-anat_t2star_2iso
# 13              19-anat_t2star_2iso
# 14              20-anat_3DT2_0.9iso
# 15              21-anat_3DT2_0.9iso
# 16    22-RUNx_rs_3mmiso_TR2.4_44cpe
# 17    24-RUNx_er_3mmiso_TR2.4_44cpe
# Name: series_id, dtype: object
# Sub-15
# 0                       1-AUTOALIGN
# 1                       2-AUTOALIGN
# 2                       3-AUTOALIGN
# 3                       4-AUTOALIGN
# 4                5-LOCA_T1_FL2D_SAG
# 5               6-RUNx_QC_tilt25_AP
# 6      8-RUNx_rs_3mmiso_TR2.4_44cpe
# 7     10-RUNx_er_3mmiso_TR2.4_44cpe
# 8               12-anat_3DT1_0.9iso
# 9               13-anat_3DT1_0.9iso
# 10    14-RUNx_rs_3mmiso_TR2.4_44cpe
# 11    16-RUNx_er_3mmiso_TR2.4_44cpe
# 12              18-anat_t2star_2iso
# 13              19-anat_t2star_2iso
# 14              20-anat_3DT2_0.9iso
# 15              21-anat_3DT2_0.9iso
# 16    22-RUNx_rs_3mmiso_TR2.4_44cpe
# 17    24-RUNx_er_3mmiso_TR2.4_44cpe
# Name: series_id, dtype: object
# Sub-16
# 0                       1-AUTOALIGN
# 1                       2-AUTOALIGN
# 2                       3-AUTOALIGN
# 3                       4-AUTOALIGN
# 4                5-LOCA_T1_FL2D_SAG
# 5               7-RUNx_QC_tilt25_AP
# 6      8-RUNx_rs_3mmiso_TR2.4_44cpe
# 7     10-RUNx_er_3mmiso_TR2.4_44cpe
# 8               12-anat_t2star_2iso
# 9               13-anat_t2star_2iso
# 10              14-anat_3DT2_0.9iso
# 11              15-anat_3DT2_0.9iso
# 12    16-RUNx_rs_3mmiso_TR2.4_44cpe
# 13    18-RUNx_er_3mmiso_TR2.4_44cpe
# 14                     20-AUTOALIGN
# 15                     21-AUTOALIGN
# 16                     22-AUTOALIGN
# 17                     23-AUTOALIGN
# 18              24-LOCA_T1_FL2D_SAG
# 19             26-RUNx_QC_tilt25_AP
# 20              27-anat_3DT1_0.9iso
# 21              28-anat_3DT1_0.9iso
# 22    29-RUNx_rs_3mmiso_TR2.4_44cpe
# 23    31-RUNx_er_3mmiso_TR2.4_44cpe
# 24    33-RUNx_rs_3mmiso_TR2.4_44cpe
# 25    35-RUNx_er_3mmiso_TR2.4_44cpe
# Name: series_id, dtype: object
# Sub-17
# 0                       1-AUTOALIGN
# 1                       2-AUTOALIGN
# 2                       3-AUTOALIGN
# 3                       4-AUTOALIGN
# 4                5-LOCA_T1_FL2D_SAG
# 5               7-RUNx_QC_tilt25_AP
# 6      8-RUNx_rs_3mmiso_TR2.4_44cpe
# 7     10-RUNx_er_3mmiso_TR2.4_44cpe
# 8               12-anat_t2star_2iso
# 9               13-anat_t2star_2iso
# 10              14-anat_3DT2_0.9iso
# 11              15-anat_3DT2_0.9iso
# 12    16-RUNx_rs_3mmiso_TR2.4_44cpe
# 13    18-RUNx_er_3mmiso_TR2.4_44cpe
# 14              20-anat_3DT1_0.9iso
# 15              21-anat_3DT1_0.9iso
# 16    22-RUNx_rs_3mmiso_TR2.4_44cpe
# 17    24-RUNx_er_3mmiso_TR2.4_44cpe
# Name: series_id, dtype: object
# Sub-18
# 0                       1-AUTOALIGN
# 1                       2-AUTOALIGN
# 2                       3-AUTOALIGN
# 3                       4-AUTOALIGN
# 4                5-LOCA_T1_FL2D_SAG
# 5               7-RUNx_QC_tilt25_AP
# 6      8-RUNx_rs_3mmiso_TR2.4_44cpe
# 7     10-RUNx_er_3mmiso_TR2.4_44cpe
# 8               12-anat_t2star_2iso
# 9               13-anat_t2star_2iso
# 10              14-anat_3DT2_0.9iso
# 11              15-anat_3DT2_0.9iso
# 12    16-RUNx_rs_3mmiso_TR2.4_44cpe
# 13    18-RUNx_er_3mmiso_TR2.4_44cpe
# 14              20-anat_3DT1_0.9iso
# 15              21-anat_3DT1_0.9iso
# 16    22-RUNx_rs_3mmiso_TR2.4_44cpe
# 17    24-RUNx_er_3mmiso_TR2.4_44cpe
# Name: series_id, dtype: object
# Sub-19
# 0                       1-AUTOALIGN
# 1                       2-AUTOALIGN
# 2                       3-AUTOALIGN
# 3                       4-AUTOALIGN
# 4                5-LOCA_T1_FL2D_SAG
# 5               6-RUNx_QC_tilt25_AP
# 6      8-RUNx_rs_3mmiso_TR2.4_44cpe
# 7     10-RUNx_er_3mmiso_TR2.4_44cpe
# 8               12-anat_3DT1_0.9iso
# 9               13-anat_3DT1_0.9iso
# 10    14-RUNx_rs_3mmiso_TR2.4_44cpe
# 11    16-RUNx_er_3mmiso_TR2.4_44cpe
# 12              18-anat_t2star_2iso
# 13              19-anat_t2star_2iso
# 14              20-anat_3DT2_0.9iso
# 15              21-anat_3DT2_0.9iso
# 16    22-RUNx_rs_3mmiso_TR2.4_44cpe
# 17    24-RUNx_er_3mmiso_TR2.4_44cpe
# Name: series_id, dtype: object
# Sub-20
# 0                       1-AUTOALIGN
# 1                       2-AUTOALIGN
# 2                       3-AUTOALIGN
# 3                       4-AUTOALIGN
# 4                5-LOCA_T1_FL2D_SAG
# 5               6-RUNx_QC_tilt25_AP
# 6      8-RUNx_rs_3mmiso_TR2.4_44cpe
# 7     10-RUNx_er_3mmiso_TR2.4_44cpe
# 8               12-anat_3DT1_0.9iso
# 9               13-anat_3DT1_0.9iso
# 10    14-RUNx_rs_3mmiso_TR2.4_44cpe
# 11    16-RUNx_er_3mmiso_TR2.4_44cpe
# 12              18-anat_t2star_2iso
# 13              19-anat_t2star_2iso
# 14              20-anat_3DT2_0.9iso
# 15              21-anat_3DT2_0.9iso
# 16    22-RUNx_rs_3mmiso_TR2.4_44cpe
# 17    24-RUNx_er_3mmiso_TR2.4_44cpe
# Name: series_id, dtype: object
# Sub-21
# 0                       1-AUTOALIGN
# 1                       2-AUTOALIGN
# 2                       3-AUTOALIGN
# 3                       4-AUTOALIGN
# 4                5-LOCA_T1_FL2D_SAG
# 5               7-RUNx_QC_tilt25_AP
# 6      8-RUNx_rs_3mmiso_TR2.4_44cpe
# 7     10-RUNx_er_3mmiso_TR2.4_44cpe
# 8               12-anat_t2star_2iso
# 9               13-anat_t2star_2iso
# 10              14-anat_3DT2_0.9iso
# 11              15-anat_3DT2_0.9iso
# 12    16-RUNx_rs_3mmiso_TR2.4_44cpe
# 13    18-RUNx_er_3mmiso_TR2.4_44cpe
# 14              20-anat_3DT1_0.9iso
# 15              21-anat_3DT1_0.9iso
# 16    22-RUNx_rs_3mmiso_TR2.4_44cpe
# 17    24-RUNx_er_3mmiso_TR2.4_44cpe
# Name: series_id, dtype: object
# Sub-22
# 0                       1-AUTOALIGN
# 1                       2-AUTOALIGN
# 2                       3-AUTOALIGN
# 3                       4-AUTOALIGN
# 4                5-LOCA_T1_FL2D_SAG
# 5               6-RUNx_QC_tilt25_AP
# 6      8-RUNx_rs_3mmiso_TR2.4_44cpe
# 7     10-RUNx_er_3mmiso_TR2.4_44cpe
# 8               12-anat_t2star_2iso
# 9               13-anat_t2star_2iso
# 10              14-anat_3DT2_0.9iso
# 11              15-anat_3DT2_0.9iso
# 12    16-RUNx_rs_3mmiso_TR2.4_44cpe
# 13    18-RUNx_er_3mmiso_TR2.4_44cpe
# 14              20-anat_3DT1_0.9iso
# 15              21-anat_3DT1_0.9iso
# 16    22-RUNx_rs_3mmiso_TR2.4_44cpe
# 17    24-RUNx_er_3mmiso_TR2.4_44cpe
# Name: series_id, dtype: object
# Sub-23
# 0                       1-AUTOALIGN
# 1                       2-AUTOALIGN
# 2                       3-AUTOALIGN
# 3                       4-AUTOALIGN
# 4                5-LOCA_T1_FL2D_SAG
# 5               6-RUNx_QC_tilt25_AP
# 6      8-RUNx_rs_3mmiso_TR2.4_44cpe
# 7     10-RUNx_er_3mmiso_TR2.4_44cpe
# 8               12-anat_3DT1_0.9iso
# 9               13-anat_3DT1_0.9iso
# 10    14-RUNx_rs_3mmiso_TR2.4_44cpe
# 11    16-RUNx_er_3mmiso_TR2.4_44cpe
# 12              18-anat_t2star_2iso
# 13              19-anat_t2star_2iso
# 14              20-anat_3DT2_0.9iso
# 15              21-anat_3DT2_0.9iso
# 16    22-RUNx_rs_3mmiso_TR2.4_44cpe
# 17    24-RUNx_er_3mmiso_TR2.4_44cpe
# Name: series_id, dtype: object
# Sub-24
# 0                       1-AUTOALIGN
# 1                       2-AUTOALIGN
# 2                       4-AUTOALIGN
# 3                5-LOCA_T1_FL2D_SAG
# 4               7-RUNx_QC_tilt25_AP
# 5     11-RUNx_rs_3mmiso_TR2.4_44cpe
# 6     13-RUNx_er_3mmiso_TR2.4_44cpe
# 7               15-anat_t2star_2iso
# 8               16-anat_t2star_2iso
# 9               17-anat_3DT2_0.9iso
# 10              18-anat_3DT2_0.9iso
# 11    19-RUNx_rs_3mmiso_TR2.4_44cpe
# 12    21-RUNx_er_3mmiso_TR2.4_44cpe
# 13              23-anat_3DT1_0.9iso
# 14              24-anat_3DT1_0.9iso
# 15    25-RUNx_rs_3mmiso_TR2.4_44cpe
# 16    27-RUNx_er_3mmiso_TR2.4_44cpe
# Name: series_id, dtype: object
# Sub-25
# 0                       1-AUTOALIGN
# 1                       2-AUTOALIGN
# 2                       3-AUTOALIGN
# 3                       4-AUTOALIGN
# 4                5-LOCA_T1_FL2D_SAG
# 5               6-RUNx_QC_tilt25_AP
# 6      8-RUNx_rs_3mmiso_TR2.4_44cpe
# 7     12-RUNx_er_3mmiso_TR2.4_44cpe
# 8               14-anat_t2star_2iso
# 9               15-anat_t2star_2iso
# 10              16-anat_3DT2_0.9iso
# 11              17-anat_3DT2_0.9iso
# 12    18-RUNx_rs_3mmiso_TR2.4_44cpe
# 13    20-RUNx_er_3mmiso_TR2.4_44cpe
# 14              22-anat_3DT1_0.9iso
# 15              23-anat_3DT1_0.9iso
# 16    24-RUNx_rs_3mmiso_TR2.4_44cpe
# 17    26-RUNx_er_3mmiso_TR2.4_44cpe
# Name: series_id, dtype: object
# Sub-26
# 0                       1-AUTOALIGN
# 1                       2-AUTOALIGN
# 2                       3-AUTOALIGN
# 3                       4-AUTOALIGN
# 4                5-LOCA_T1_FL2D_SAG
# 5               6-RUNx_QC_tilt25_AP
# 6      8-RUNx_rs_3mmiso_TR2.4_44cpe
# 7     10-RUNx_er_3mmiso_TR2.4_44cpe
# 8               12-anat_3DT1_0.9iso
# 9               13-anat_3DT1_0.9iso
# 10    14-RUNx_rs_3mmiso_TR2.4_44cpe
# 11    16-RUNx_er_3mmiso_TR2.4_44cpe
# 12              18-anat_t2star_2iso
# 13              19-anat_t2star_2iso
# 14              20-anat_3DT2_0.9iso
# 15              21-anat_3DT2_0.9iso
# 16    22-RUNx_rs_3mmiso_TR2.4_44cpe
# 17    24-RUNx_er_3mmiso_TR2.4_44cpe
# Name: series_id, dtype: object
# Sub-27
# 0                       1-AUTOALIGN
# 1                       2-AUTOALIGN
# 2                       3-AUTOALIGN
# 3                       4-AUTOALIGN
# 4                5-LOCA_T1_FL2D_SAG
# 5               6-RUNx_QC_tilt25_AP
# 6      9-RUNx_rs_3mmiso_TR2.4_44cpe
# 7     11-RUNx_er_3mmiso_TR2.4_44cpe
# 8               13-anat_3DT1_0.9iso
# 9               14-anat_3DT1_0.9iso
# 10    15-RUNx_rs_3mmiso_TR2.4_44cpe
# 11    17-RUNx_er_3mmiso_TR2.4_44cpe
# 12                     19-AUTOALIGN
# 13                     20-AUTOALIGN
# 14                     21-AUTOALIGN
# 15                     22-AUTOALIGN
# 16              23-LOCA_T1_FL2D_SAG
# 17             24-RUNx_QC_tilt25_AP
# 18    26-RUNx_rs_3mmiso_TR2.4_44cpe
# 19    28-RUNx_er_3mmiso_TR2.4_44cpe
# 20              30-anat_t2star_2iso
# 21              31-anat_t2star_2iso
# 22              32-anat_3DT2_0.9iso
# 23              33-anat_3DT2_0.9iso
# 24    34-RUNx_rs_3mmiso_TR2.4_44cpe
# 25    36-RUNx_er_3mmiso_TR2.4_44cpe
# Name: series_id, dtype: object
# Sub-28
# 0                       1-AUTOALIGN
# 1                       2-AUTOALIGN
# 2                       3-AUTOALIGN
# 3                       4-AUTOALIGN
# 4                5-LOCA_T1_FL2D_SAG
# 5               6-RUNx_QC_tilt25_AP
# 6      8-RUNx_rs_3mmiso_TR2.4_44cpe
# 7     10-RUNx_er_3mmiso_TR2.4_44cpe
# 8               12-anat_3DT1_0.9iso
# 9               13-anat_3DT1_0.9iso
# 10    14-RUNx_rs_3mmiso_TR2.4_44cpe
# 11    16-RUNx_er_3mmiso_TR2.4_44cpe
# 12              18-anat_t2star_2iso
# 13              19-anat_t2star_2iso
# 14              20-anat_3DT2_0.9iso
# 15              21-anat_3DT2_0.9iso
# 16    22-RUNx_rs_3mmiso_TR2.4_44cpe
# 17    24-RUNx_er_3mmiso_TR2.4_44cpe
# 18             100-anat_3DT1_0.9iso
# Name: series_id, dtype: object
# Sub-29
# 0                       1-AUTOALIGN
# 1                       2-AUTOALIGN
# 2                       3-AUTOALIGN
# 3                       4-AUTOALIGN
# 4                5-LOCA_T1_FL2D_SAG
# 5               6-RUNx_QC_tilt25_AP
# 6      8-RUNx_rs_3mmiso_TR2.4_44cpe
# 7     10-RUNx_er_3mmiso_TR2.4_44cpe
# 8               12-anat_3DT1_0.9iso
# 9               13-anat_3DT1_0.9iso
# 10    14-RUNx_rs_3mmiso_TR2.4_44cpe
# 11    16-RUNx_er_3mmiso_TR2.4_44cpe
# 12              18-anat_t2star_2iso
# 13              19-anat_t2star_2iso
# 14              20-anat_3DT2_0.9iso
# 15              21-anat_3DT2_0.9iso
# 16    22-RUNx_rs_3mmiso_TR2.4_44cpe
# 17    24-RUNx_er_3mmiso_TR2.4_44cpe
# Name: series_id, dtype: object
# Sub-30
# 0                       1-AUTOALIGN
# 1                       2-AUTOALIGN
# 2                       3-AUTOALIGN
# 3                       4-AUTOALIGN
# 4                5-LOCA_T1_FL2D_SAG
# 5               7-RUNx_QC_tilt25_AP
# 6               9-RUNx_QC_tilt25_AP
# 7     10-RUNx_rs_3mmiso_TR2.4_44cpe
# 8     12-RUNx_er_3mmiso_TR2.4_44cpe
# 9               14-anat_t2star_2iso
# 10              15-anat_t2star_2iso
# 11              16-anat_3DT2_0.9iso
# 12              17-anat_3DT2_0.9iso
# 13    18-RUNx_rs_3mmiso_TR2.4_44cpe
# 14    20-RUNx_er_3mmiso_TR2.4_44cpe
# 15              22-anat_3DT1_0.9iso
# 16              23-anat_3DT1_0.9iso
# 17    24-RUNx_rs_3mmiso_TR2.4_44cpe
# 18    26-RUNx_er_3mmiso_TR2.4_44cpe
# Name: series_id, dtype: object
# Sub-31
# 0                       1-AUTOALIGN
# 1                       2-AUTOALIGN
# 2                       3-AUTOALIGN
# 3                       4-AUTOALIGN
# 4                5-LOCA_T1_FL2D_SAG
# 5               6-RUNx_QC_tilt25_AP
# 6      8-RUNx_rs_3mmiso_TR2.4_44cpe
# 7     10-RUNx_er_3mmiso_TR2.4_44cpe
# 8               12-anat_t2star_2iso
# 9               13-anat_t2star_2iso
# 10              14-anat_3DT2_0.9iso
# 11              15-anat_3DT2_0.9iso
# 12    16-RUNx_rs_3mmiso_TR2.4_44cpe
# 13    18-RUNx_er_3mmiso_TR2.4_44cpe
# 14              20-anat_3DT1_0.9iso
# 15              21-anat_3DT1_0.9iso
# 16    22-RUNx_rs_3mmiso_TR2.4_44cpe
# 17    24-RUNx_er_3mmiso_TR2.4_44cpe
# Name: series_id, dtype: object
# Sub-32
# 0                        1-AUTOALIGN
# 1                        2-AUTOALIGN
# 2                        3-AUTOALIGN
# 3                        4-AUTOALIGN
# 4                 5-LOCA_T1_FL2D_SAG
# 5                7-RUNx_QC_tilt25_AP
# 6       8-RUNx_rs_3mmiso_TR2.4_44cpe
# 7      10-RUNx_er_3mmiso_TR2.4_44cpe
# 8                12-anat_t2star_2iso
# 9                13-anat_t2star_2iso
# 10               14-anat_3DT2_0.9iso
# 11               15-anat_3DT2_0.9iso
# 12     16-RUNx_rs_3mmiso_TR2.4_44cpe
# 13     18-RUNx_er_3mmiso_TR2.4_44cpe
# 14               20-anat_3DT1_0.9iso
# 15               21-anat_3DT1_0.9iso
# 16     22-RUNx_rs_3mmiso_TR2.4_44cpe
# 17     24-RUNx_er_3mmiso_TR2.4_44cpe
# 18             100-RUNx_QC_tilt25_AP
# 19    101-RUNx_rs_3mmiso_TR2.4_44cpe
# 20             5001-LOCA_T1_FL2D_SAG
# 21             5002-LOCA_T1_FL2D_SAG
# 22             5003-LOCA_T1_FL2D_SAG
# Name: series_id, dtype: object
# Sub-33
# 0                       1-AUTOALIGN
# 1                       2-AUTOALIGN
# 2                       3-AUTOALIGN
# 3                       4-AUTOALIGN
# 4                5-LOCA_T1_FL2D_SAG
# 5               6-RUNx_QC_tilt25_AP
# 6      8-RUNx_rs_3mmiso_TR2.4_44cpe
# 7     10-RUNx_er_3mmiso_TR2.4_44cpe
# 8               12-anat_3DT1_0.9iso
# 9               13-anat_3DT1_0.9iso
# 10    14-RUNx_rs_3mmiso_TR2.4_44cpe
# 11    16-RUNx_er_3mmiso_TR2.4_44cpe
# 12              18-anat_t2star_2iso
# 13              19-anat_t2star_2iso
# 14              20-anat_3DT2_0.9iso
# 15              21-anat_3DT2_0.9iso
# 16    22-RUNx_rs_3mmiso_TR2.4_44cpe
# 17    24-RUNx_er_3mmiso_TR2.4_44cpe
# Name: series_id, dtype: object
# Sub-34
# 0                       1-AUTOALIGN
# 1                       2-AUTOALIGN
# 2                       3-AUTOALIGN
# 3                       4-AUTOALIGN
# 4                5-LOCA_T1_FL2D_SAG
# 5               7-RUNx_QC_tilt25_AP
# 6      8-RUNx_rs_3mmiso_TR2.4_44cpe
# 7     10-RUNx_er_3mmiso_TR2.4_44cpe
# 8               12-anat_t2star_2iso
# 9               13-anat_t2star_2iso
# 10              14-anat_3DT2_0.9iso
# 11              15-anat_3DT2_0.9iso
# 12    16-RUNx_rs_3mmiso_TR2.4_44cpe
# 13    18-RUNx_er_3mmiso_TR2.4_44cpe
# 14              20-anat_3DT1_0.9iso
# 15              21-anat_3DT1_0.9iso
# 16    22-RUNx_rs_3mmiso_TR2.4_44cpe
# 17    24-RUNx_er_3mmiso_TR2.4_44cpe
# Name: series_id, dtype: object
# Sub-35
# 0                       1-AUTOALIGN
# 1                       2-AUTOALIGN
# 2                       3-AUTOALIGN
# 3                       4-AUTOALIGN
# 4                5-LOCA_T1_FL2D_SAG
# 5               7-RUNx_QC_tilt25_AP
# 6      8-RUNx_rs_3mmiso_TR2.4_44cpe
# 7     10-RUNx_er_3mmiso_TR2.4_44cpe
# 8               12-anat_t2star_2iso
# 9               13-anat_t2star_2iso
# 10              14-anat_3DT2_0.9iso
# 11              15-anat_3DT2_0.9iso
# 12    16-RUNx_rs_3mmiso_TR2.4_44cpe
# 13    18-RUNx_er_3mmiso_TR2.4_44cpe
# 14              20-anat_3DT1_0.9iso
# 15              21-anat_3DT1_0.9iso
# 16    22-RUNx_rs_3mmiso_TR2.4_44cpe
# 17    24-RUNx_er_3mmiso_TR2.4_44cpe
# Name: series_id, dtype: object
# Sub-36
# 0                       1-AUTOALIGN
# 1                       2-AUTOALIGN
# 2                       3-AUTOALIGN
# 3                       4-AUTOALIGN
# 4                5-LOCA_T1_FL2D_SAG
# 5               6-RUNx_QC_tilt25_AP
# 6      8-RUNx_rs_3mmiso_TR2.4_44cpe
# 7     10-RUNx_er_3mmiso_TR2.4_44cpe
# 8               12-anat_t2star_2iso
# 9               13-anat_t2star_2iso
# 10              14-anat_3DT2_0.9iso
# 11              15-anat_3DT2_0.9iso
# 12    16-RUNx_rs_3mmiso_TR2.4_44cpe
# 13    18-RUNx_er_3mmiso_TR2.4_44cpe
# 14              20-anat_3DT1_0.9iso
# 15              21-anat_3DT1_0.9iso
# 16    22-RUNx_rs_3mmiso_TR2.4_44cpe
# 17    24-RUNx_er_3mmiso_TR2.4_44cpe
# Name: series_id, dtype: object
# Sub-37
# 0                       1-AUTOALIGN
# 1                       2-AUTOALIGN
# 2                       3-AUTOALIGN
# 3                       4-AUTOALIGN
# 4                5-LOCA_T1_FL2D_SAG
# 5               7-RUNx_QC_tilt25_AP
# 6      8-RUNx_rs_3mmiso_TR2.4_44cpe
# 7     10-RUNx_er_3mmiso_TR2.4_44cpe
# 8               12-anat_t2star_2iso
# 9               13-anat_t2star_2iso
# 10              14-anat_3DT2_0.9iso
# 11              15-anat_3DT2_0.9iso
# 12    16-RUNx_rs_3mmiso_TR2.4_44cpe
# 13    18-RUNx_er_3mmiso_TR2.4_44cpe
# 14              20-anat_3DT1_0.9iso
# 15              21-anat_3DT1_0.9iso
# 16    22-RUNx_rs_3mmiso_TR2.4_44cpe
# 17    24-RUNx_er_3mmiso_TR2.4_44cpe
# Name: series_id, dtype: object
# Sub-38
# 0                       1-AUTOALIGN
# 1                       2-AUTOALIGN
# 2                       3-AUTOALIGN
# 3                       4-AUTOALIGN
# 4                5-LOCA_T1_FL2D_SAG
# 5               7-RUNx_QC_tilt25_AP
# 6      8-RUNx_rs_3mmiso_TR2.4_44cpe
# 7     10-RUNx_er_3mmiso_TR2.4_44cpe
# 8               12-anat_t2star_2iso
# 9               13-anat_t2star_2iso
# 10              14-anat_3DT2_0.9iso
# 11              15-anat_3DT2_0.9iso
# 12    16-RUNx_rs_3mmiso_TR2.4_44cpe
# 13    18-RUNx_er_3mmiso_TR2.4_44cpe
# 14              20-anat_3DT1_0.9iso
# 15              21-anat_3DT1_0.9iso
# 16    22-RUNx_rs_3mmiso_TR2.4_44cpe
# 17    24-RUNx_er_3mmiso_TR2.4_44cpe
# Name: series_id, dtype: object
# Sub-39
# 0                       1-AUTOALIGN
# 1                       2-AUTOALIGN
# 2                       3-AUTOALIGN
# 3                       4-AUTOALIGN
# 4                5-LOCA_T1_FL2D_SAG
# 5               6-RUNx_QC_tilt25_AP
# 6      8-RUNx_rs_3mmiso_TR2.4_44cpe
# 7     10-RUNx_er_3mmiso_TR2.4_44cpe
# 8               12-anat_3DT1_0.9iso
# 9               13-anat_3DT1_0.9iso
# 10    14-RUNx_rs_3mmiso_TR2.4_44cpe
# 11    16-RUNx_er_3mmiso_TR2.4_44cpe
# 12              18-anat_t2star_2iso
# 13              19-anat_t2star_2iso
# 14              20-anat_3DT2_0.9iso
# 15              21-anat_3DT2_0.9iso
# 16    22-RUNx_rs_3mmiso_TR2.4_44cpe
# 17    24-RUNx_er_3mmiso_TR2.4_44cpe
# Name: series_id, dtype: object
# Sub-40
# 0                       1-AUTOALIGN
# 1                       2-AUTOALIGN
# 2                       3-AUTOALIGN
# 3                       4-AUTOALIGN
# 4                5-LOCA_T1_FL2D_SAG
# 5               7-RUNx_QC_tilt25_AP
# 6      8-RUNx_rs_3mmiso_TR2.4_44cpe
# 7     10-RUNx_er_3mmiso_TR2.4_44cpe
# 8               12-anat_t2star_2iso
# 9               13-anat_t2star_2iso
# 10              14-anat_3DT2_0.9iso
# 11              15-anat_3DT2_0.9iso
# 12    16-RUNx_rs_3mmiso_TR2.4_44cpe
# 13    18-RUNx_er_3mmiso_TR2.4_44cpe
# 14              20-anat_3DT1_0.9iso
# 15              21-anat_3DT1_0.9iso
# 16    22-RUNx_rs_3mmiso_TR2.4_44cpe
# 17    24-RUNx_er_3mmiso_TR2.4_44cpe
# Name: series_id, dtype: object

# %%
print('T1',np.unique(dcm_df['T1']))
print(70*'-')
print('T2',np.unique(dcm_df['T2']))
print(70*'-')
print('T2*',np.unique(dcm_df['T2*']))
print(70*'-')
print('RS',np.unique(dcm_df['RS']))
# Out:
# T1 [list(['12', '13']) list(['13', '14']) list(['19', '20'])
#  list(['20', '21']) list(['20', '21', '26', '27']) list(['22', '23'])
#  list(['23', '24']) list(['26', '27']) list(['27', '28'])]
# ----------------------------------------------------------------------
# T2 [list(['14', '15']) list(['16', '17']) list(['17', '18'])
#  list(['20', '21']) list(['27', '28']) list(['32', '33'])]
# ----------------------------------------------------------------------
# T2* [list(['12', '13']) list(['12', '13', '5001']) list(['14', '15'])
#  list(['15', '16']) list(['18', '19']) list(['25', '26'])
#  list(['30', '31'])]
# ----------------------------------------------------------------------
# RS [list(['10', '18', '24']) list(['11', '19', '25'])
#  list(['14', '22', '28']) list(['15', '21', '29']) list(['8', '14', '22'])
#  list(['8', '16', '22']) list(['8', '16', '22', '101', '5003'])
#  list(['8', '16', '29']) list(['8', '16', '29', '33'])
#  list(['8', '18', '24']) list(['9', '15', '26', '34'])]

# %%
#d.DataFrame.from_dict(infos_dict_indxs, orient='index')

# %% [markdown]
# ### Get the differences between subjects datas
#
# Using difflib : https://towardsdatascience.com/find-the-difference-in-python-68bbd000e513

# %%
dcm_df
# Out:
#                             RS                T1        T2             T2*
# Sub-1              [8, 16, 22]  [20, 21, 26, 27]  [14, 15]        [12, 13]
# Sub-2              [8, 16, 22]          [20, 21]  [14, 15]        [12, 13]
# Sub-3              [8, 16, 22]          [20, 21]  [14, 15]        [12, 13]
# Sub-4              [8, 16, 22]          [20, 21]  [14, 15]        [12, 13]
# Sub-5             [14, 22, 28]          [26, 27]  [20, 21]        [18, 19]
# Sub-6              [8, 16, 22]          [20, 21]  [14, 15]        [12, 13]
# Sub-7             [15, 21, 29]          [19, 20]  [27, 28]        [25, 26]
# Sub-8              [8, 14, 22]          [12, 13]  [20, 21]        [18, 19]
# Sub-9              [8, 16, 22]          [20, 21]  [14, 15]        [12, 13]
# Sub-10             [8, 16, 22]          [20, 21]  [14, 15]        [12, 13]
# Sub-11             [8, 14, 22]          [12, 13]  [20, 21]        [18, 19]
# Sub-12             [8, 16, 29]          [27, 28]  [14, 15]        [12, 13]
# Sub-13             [8, 16, 22]          [20, 21]  [14, 15]        [12, 13]
# Sub-14             [8, 14, 22]          [12, 13]  [20, 21]        [18, 19]
# Sub-15             [8, 14, 22]          [12, 13]  [20, 21]        [18, 19]
# Sub-16         [8, 16, 29, 33]          [27, 28]  [14, 15]        [12, 13]
# Sub-17             [8, 16, 22]          [20, 21]  [14, 15]        [12, 13]
# Sub-18             [8, 16, 22]          [20, 21]  [14, 15]        [12, 13]
# Sub-19             [8, 14, 22]          [12, 13]  [20, 21]        [18, 19]
# Sub-20             [8, 14, 22]          [12, 13]  [20, 21]        [18, 19]
# Sub-21             [8, 16, 22]          [20, 21]  [14, 15]        [12, 13]
# Sub-22             [8, 16, 22]          [20, 21]  [14, 15]        [12, 13]
# Sub-23             [8, 14, 22]          [12, 13]  [20, 21]        [18, 19]
# Sub-24            [11, 19, 25]          [23, 24]  [17, 18]        [15, 16]
# Sub-25             [8, 18, 24]          [22, 23]  [16, 17]        [14, 15]
# Sub-26             [8, 14, 22]          [12, 13]  [20, 21]        [18, 19]
# Sub-27         [9, 15, 26, 34]          [13, 14]  [32, 33]        [30, 31]
# Sub-28             [8, 14, 22]          [12, 13]  [20, 21]        [18, 19]
# Sub-29             [8, 14, 22]          [12, 13]  [20, 21]        [18, 19]
# Sub-30            [10, 18, 24]          [22, 23]  [16, 17]        [14, 15]
# Sub-31             [8, 16, 22]          [20, 21]  [14, 15]        [12, 13]
# Sub-32  [8, 16, 22, 101, 5003]          [20, 21]  [14, 15]  [12, 13, 5001]
# Sub-33             [8, 14, 22]          [12, 13]  [20, 21]        [18, 19]
# Sub-34             [8, 16, 22]          [20, 21]  [14, 15]        [12, 13]
# Sub-35             [8, 16, 22]          [20, 21]  [14, 15]        [12, 13]
# Sub-36             [8, 16, 22]          [20, 21]  [14, 15]        [12, 13]
# Sub-37             [8, 16, 22]          [20, 21]  [14, 15]        [12, 13]
# Sub-38             [8, 16, 22]          [20, 21]  [14, 15]        [12, 13]
# Sub-39             [8, 14, 22]          [12, 13]  [20, 21]        [18, 19]
# Sub-40             [8, 16, 22]          [20, 21]  [14, 15]        [12, 13]
