# %% [markdown]
# “Gradient” approaches : define the brain as a set of continuous scores along manifold axes (≠ parcellisation into distinct areas based on anatomical functions or features)
#
# Core gradient technique :
# 1. **computation of an affinity matrix** that captures inter-area similarity of a given feature
# 2. application of **dimensionality reduction** method (here diffusion embedding) to identify a gradual ordering of the input matrix in a lower dimensional manifold space.
#
#
#
#
#
# Ressources
#
# - https://brainspace.readthedocs.io/en/latest/pages/install.html
# - https://brainspace.readthedocs.io/en/latest/pages/getting_started.html

# %%
# !git clone https://github.com/MICA-MNI/BrainSpace.git
# !pip install load_confounds
# !pip install vtk
# !pip install "nilearn>=0.9.0"

# %cd BrainSpace
# !python setup.py install
# Out:
# fatal: le chemin de destination 'BrainSpace' existe déjà et n'est pas un répertoire vide.
# Requirement already satisfied: load_confounds in /home/romy.beaute/anaconda3/lib/python3.9/site-packages (0.12.0)
# Requirement already satisfied: scipy>=1.3.2 in /home/romy.beaute/anaconda3/lib/python3.9/site-packages (from load_confounds) (1.7.3)
# Requirement already satisfied: nilearn>=0.7.1 in /home/romy.beaute/anaconda3/lib/python3.9/site-packages (from load_confounds) (0.9.1)
# Requirement already satisfied: numpy>=1.17.4 in /home/romy.beaute/anaconda3/lib/python3.9/site-packages (from load_confounds) (1.21.5)
# Requirement already satisfied: scikit-learn>=0.21.3 in /home/romy.beaute/anaconda3/lib/python3.9/site-packages (from load_confounds) (1.0.2)
# Requirement already satisfied: pandas>=0.25.3 in /home/romy.beaute/anaconda3/lib/python3.9/site-packages (from load_confounds) (1.4.2)
# Requirement already satisfied: nibabel>=3.0.0 in /home/romy.beaute/anaconda3/lib/python3.9/site-packages (from nilearn>=0.7.1->load_confounds) (3.2.2)
# Requirement already satisfied: requests>=2 in /home/romy.beaute/anaconda3/lib/python3.9/site-packages (from nilearn>=0.7.1->load_confounds) (2.27.1)
# Requirement already satisfied: joblib>=0.15 in /home/romy.beaute/anaconda3/lib/python3.9/site-packages (from nilearn>=0.7.1->load_confounds) (1.1.0)
# Requirement already satisfied: lxml in /home/romy.beaute/anaconda3/lib/python3.9/site-packages (from nilearn>=0.7.1->load_confounds) (4.8.0)
# Requirement already satisfied: packaging>=14.3 in /home/romy.beaute/anaconda3/lib/python3.9/site-packages (from nibabel>=3.0.0->nilearn>=0.7.1->load_confounds) (21.3)
# Requirement already satisfied: setuptools in /home/romy.beaute/anaconda3/lib/python3.9/site-packages (from nibabel>=3.0.0->nilearn>=0.7.1->load_confounds) (61.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/romy.beaute/anaconda3/lib/python3.9/site-packages (from packaging>=14.3->nibabel>=3.0.0->nilearn>=0.7.1->load_confounds) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/romy.beaute/anaconda3/lib/python3.9/site-packages (from pandas>=0.25.3->load_confounds) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/romy.beaute/anaconda3/lib/python3.9/site-packages (from pandas>=0.25.3->load_confounds) (2021.3)
# Requirement already satisfied: six>=1.5 in /home/romy.beaute/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas>=0.25.3->load_confounds) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/romy.beaute/anaconda3/lib/python3.9/site-packages (from requests>=2->nilearn>=0.7.1->load_confounds) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/romy.beaute/anaconda3/lib/python3.9/site-packages (from requests>=2->nilearn>=0.7.1->load_confounds) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/romy.beaute/anaconda3/lib/python3.9/site-packages (from requests>=2->nilearn>=0.7.1->load_confounds) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in /home/romy.beaute/anaconda3/lib/python3.9/site-packages (from requests>=2->nilearn>=0.7.1->load_confounds) (3.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/romy.beaute/anaconda3/lib/python3.9/site-packages (from scikit-learn>=0.21.3->load_confounds) (2.2.0)
# Requirement already satisfied: vtk in /home/romy.beaute/anaconda3/lib/python3.9/site-packages (9.1.0)
# Requirement already satisfied: wslink>=1.0.4 in /home/romy.beaute/anaconda3/lib/python3.9/site-packages (from vtk) (1.6.5)
# Requirement already satisfied: matplotlib>=2.0.0 in /home/romy.beaute/anaconda3/lib/python3.9/site-packages (from vtk) (3.5.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/romy.beaute/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.0.0->vtk) (2.8.2)
# Requirement already satisfied: numpy>=1.17 in /home/romy.beaute/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.0.0->vtk) (1.21.5)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/romy.beaute/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.0.0->vtk) (3.0.4)
# Requirement already satisfied: pillow>=6.2.0 in /home/romy.beaute/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.0.0->vtk) (9.0.1)
# Requirement already satisfied: cycler>=0.10 in /home/romy.beaute/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.0.0->vtk) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/romy.beaute/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.0.0->vtk) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/romy.beaute/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.0.0->vtk) (1.3.2)
# Requirement already satisfied: packaging>=20.0 in /home/romy.beaute/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.0.0->vtk) (21.3)
# Requirement already satisfied: six>=1.5 in /home/romy.beaute/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=2.0.0->vtk) (1.16.0)
# Requirement already satisfied: aiohttp in /home/romy.beaute/anaconda3/lib/python3.9/site-packages (from wslink>=1.0.4->vtk) (3.8.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/romy.beaute/anaconda3/lib/python3.9/site-packages (from aiohttp->wslink>=1.0.4->vtk) (21.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/romy.beaute/anaconda3/lib/python3.9/site-packages (from aiohttp->wslink>=1.0.4->vtk) (1.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/romy.beaute/anaconda3/lib/python3.9/site-packages (from aiohttp->wslink>=1.0.4->vtk) (1.6.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/romy.beaute/anaconda3/lib/python3.9/site-packages (from aiohttp->wslink>=1.0.4->vtk) (5.2.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /home/romy.beaute/anaconda3/lib/python3.9/site-packages (from aiohttp->wslink>=1.0.4->vtk) (2.0.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/romy.beaute/anaconda3/lib/python3.9/site-packages (from aiohttp->wslink>=1.0.4->vtk) (1.2.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/romy.beaute/anaconda3/lib/python3.9/site-packages (from aiohttp->wslink>=1.0.4->vtk) (4.0.1)
# Requirement already satisfied: typing-extensions>=3.6.5 in /home/romy.beaute/anaconda3/lib/python3.9/site-packages (from async-timeout<5.0,>=4.0.0a3->aiohttp->wslink>=1.0.4->vtk) (4.1.1)
# Requirement already satisfied: idna>=2.0 in /home/romy.beaute/anaconda3/lib/python3.9/site-packages (from yarl<2.0,>=1.0->aiohttp->wslink>=1.0.4->vtk) (3.3)
# /home/romy.beaute/projects/hypnomed/BrainSpace/BrainSpace
# /home/romy.beaute/anaconda3/lib/python3.9/site-packages/setuptools/dist.py:757: UserWarning: Usage of dash-separated 'description-file' will not be supported in future versions. Please use the underscore name 'description_file' instead
#   warnings.warn(
# running install
# /home/romy.beaute/anaconda3/lib/python3.9/site-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# /home/romy.beaute/anaconda3/lib/python3.9/site-packages/setuptools/command/easy_install.py:144: EasyInstallDeprecationWarning: easy_install command is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# running bdist_egg
# running egg_info
# writing brainspace.egg-info/PKG-INFO
# writing dependency_links to brainspace.egg-info/dependency_links.txt
# writing requirements to brainspace.egg-info/requires.txt
# writing top-level names to brainspace.egg-info/top_level.txt
# reading manifest file 'brainspace.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# adding license file 'LICENSE'
# writing manifest file 'brainspace.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/brainspace
# creating build/bdist.linux-x86_64/egg/brainspace/mesh
# copying build/lib/brainspace/mesh/array_operations.py -> build/bdist.linux-x86_64/egg/brainspace/mesh
# copying build/lib/brainspace/mesh/mesh_io.py -> build/bdist.linux-x86_64/egg/brainspace/mesh
# copying build/lib/brainspace/mesh/mesh_creation.py -> build/bdist.linux-x86_64/egg/brainspace/mesh
# copying build/lib/brainspace/mesh/__init__.py -> build/bdist.linux-x86_64/egg/brainspace/mesh
# copying build/lib/brainspace/mesh/mesh_cluster.py -> build/bdist.linux-x86_64/egg/brainspace/mesh
# copying build/lib/brainspace/mesh/mesh_operations.py -> build/bdist.linux-x86_64/egg/brainspace/mesh
# copying build/lib/brainspace/mesh/mesh_correspondence.py -> build/bdist.linux-x86_64/egg/brainspace/mesh
# copying build/lib/brainspace/mesh/mesh_elements.py -> build/bdist.linux-x86_64/egg/brainspace/mesh
# creating build/bdist.linux-x86_64/egg/brainspace/null_models
# copying build/lib/brainspace/null_models/moran.py -> build/bdist.linux-x86_64/egg/brainspace/null_models
# copying build/lib/brainspace/null_models/variogram.py -> build/bdist.linux-x86_64/egg/brainspace/null_models
# copying build/lib/brainspace/null_models/__init__.py -> build/bdist.linux-x86_64/egg/brainspace/null_models
# copying build/lib/brainspace/null_models/spin.py -> build/bdist.linux-x86_64/egg/brainspace/null_models
# creating build/bdist.linux-x86_64/egg/brainspace/utils
# copying build/lib/brainspace/utils/parcellation.py -> build/bdist.linux-x86_64/egg/brainspace/utils
# copying build/lib/brainspace/utils/__init__.py -> build/bdist.linux-x86_64/egg/brainspace/utils
# creating build/bdist.linux-x86_64/egg/brainspace/datasets
# creating build/bdist.linux-x86_64/egg/brainspace/datasets/surfaces
# copying build/lib/brainspace/datasets/surfaces/conte69_32k_rh_mask.csv -> build/bdist.linux-x86_64/egg/brainspace/datasets/surfaces
# copying build/lib/brainspace/datasets/surfaces/conte69_32k_rh_temporal_mask.csv -> build/bdist.linux-x86_64/egg/brainspace/datasets/surfaces
# copying build/lib/brainspace/datasets/surfaces/conte69_32k_lh_temporal_mask.csv -> build/bdist.linux-x86_64/egg/brainspace/datasets/surfaces
# copying build/lib/brainspace/datasets/surfaces/conte69_32k_lh_sphere.gii -> build/bdist.linux-x86_64/egg/brainspace/datasets/surfaces
# copying build/lib/brainspace/datasets/surfaces/conte69_32k_lh_mask.csv -> build/bdist.linux-x86_64/egg/brainspace/datasets/surfaces
# copying build/lib/brainspace/datasets/surfaces/fsa5.pial.rh.gii -> build/bdist.linux-x86_64/egg/brainspace/datasets/surfaces
# copying build/lib/brainspace/datasets/surfaces/conte69_32k_rh.gii -> build/bdist.linux-x86_64/egg/brainspace/datasets/surfaces
# copying build/lib/brainspace/datasets/surfaces/conte69_32k_lh.gii -> build/bdist.linux-x86_64/egg/brainspace/datasets/surfaces
# copying build/lib/brainspace/datasets/surfaces/fsa5.pial.lh.gii -> build/bdist.linux-x86_64/egg/brainspace/datasets/surfaces
# copying build/lib/brainspace/datasets/surfaces/conte69_32k_rh_sphere.gii -> build/bdist.linux-x86_64/egg/brainspace/datasets/surfaces
# creating build/bdist.linux-x86_64/egg/brainspace/datasets/__pycache__
# copying build/lib/brainspace/datasets/__pycache__/__init__.cpython-39.pyc -> build/bdist.linux-x86_64/egg/brainspace/datasets/__pycache__
# copying build/lib/brainspace/datasets/__pycache__/base.cpython-39.pyc -> build/bdist.linux-x86_64/egg/brainspace/datasets/__pycache__
# creating build/bdist.linux-x86_64/egg/brainspace/datasets/preprocessing
# copying build/lib/brainspace/datasets/preprocessing/sub-010188_ses-02_task-rest_acq-AP_run-01.fsa5.rh.mgz -> build/bdist.linux-x86_64/egg/brainspace/datasets/preprocessing
# copying build/lib/brainspace/datasets/preprocessing/sub-010188_ses-02_task-rest_acq-AP_run-01.fsa5.lh.mgz -> build/bdist.linux-x86_64/egg/brainspace/datasets/preprocessing
# copying build/lib/brainspace/datasets/preprocessing/sub-010188_ses-02_task-rest_acq-AP_run-01_confounds.txt -> build/bdist.linux-x86_64/egg/brainspace/datasets/preprocessing
# copying build/lib/brainspace/datasets/base.py -> build/bdist.linux-x86_64/egg/brainspace/datasets
# copying build/lib/brainspace/datasets/__init__.py -> build/bdist.linux-x86_64/egg/brainspace/datasets
# creating build/bdist.linux-x86_64/egg/brainspace/datasets/matrices
# creating build/bdist.linux-x86_64/egg/brainspace/datasets/matrices/main_group
# copying build/lib/brainspace/datasets/matrices/main_group/conte69_32k_mpc_gradient1.csv -> build/bdist.linux-x86_64/egg/brainspace/datasets/matrices/main_group
# copying build/lib/brainspace/datasets/matrices/main_group/conte69_32k_mpc_gradient0.csv -> build/bdist.linux-x86_64/egg/brainspace/datasets/matrices/main_group
# copying build/lib/brainspace/datasets/matrices/main_group/conte69_32k_thickness.csv -> build/bdist.linux-x86_64/egg/brainspace/datasets/matrices/main_group
# copying build/lib/brainspace/datasets/matrices/main_group/conte69_32k_curvature.csv -> build/bdist.linux-x86_64/egg/brainspace/datasets/matrices/main_group
# copying build/lib/brainspace/datasets/matrices/main_group/conte69_32k_fc_gradient1.csv -> build/bdist.linux-x86_64/egg/brainspace/datasets/matrices/main_group
# copying build/lib/brainspace/datasets/matrices/main_group/schaefer_200_mean_connectivity_matrix.csv -> build/bdist.linux-x86_64/egg/brainspace/datasets/matrices/main_group
# copying build/lib/brainspace/datasets/matrices/main_group/schaefer_400_mean_connectivity_matrix.csv -> build/bdist.linux-x86_64/egg/brainspace/datasets/matrices/main_group
# copying build/lib/brainspace/datasets/matrices/main_group/vosdewael_200_mean_connectivity_matrix.csv -> build/bdist.linux-x86_64/egg/brainspace/datasets/matrices/main_group
# copying build/lib/brainspace/datasets/matrices/main_group/conte69_32k_fc_gradient0.csv -> build/bdist.linux-x86_64/egg/brainspace/datasets/matrices/main_group
# copying build/lib/brainspace/datasets/matrices/main_group/vosdewael_100_mean_connectivity_matrix.csv -> build/bdist.linux-x86_64/egg/brainspace/datasets/matrices/main_group
# copying build/lib/brainspace/datasets/matrices/main_group/vosdewael_400_mean_connectivity_matrix.csv -> build/bdist.linux-x86_64/egg/brainspace/datasets/matrices/main_group
# copying build/lib/brainspace/datasets/matrices/main_group/vosdewael_300_mean_connectivity_matrix.csv -> build/bdist.linux-x86_64/egg/brainspace/datasets/matrices/main_group
# copying build/lib/brainspace/datasets/matrices/main_group/schaefer_100_mean_connectivity_matrix.csv -> build/bdist.linux-x86_64/egg/brainspace/datasets/matrices/main_group
# copying build/lib/brainspace/datasets/matrices/main_group/conte69_32k_t1wt2w.csv -> build/bdist.linux-x86_64/egg/brainspace/datasets/matrices/main_group
# copying build/lib/brainspace/datasets/matrices/main_group/schaefer_300_mean_connectivity_matrix.csv -> build/bdist.linux-x86_64/egg/brainspace/datasets/matrices/main_group
# creating build/bdist.linux-x86_64/egg/brainspace/datasets/matrices/fusion_tutorial
# copying build/lib/brainspace/datasets/matrices/fusion_tutorial/vosdewael_200_mpc_matrix.csv -> build/bdist.linux-x86_64/egg/brainspace/datasets/matrices/fusion_tutorial
# creating build/bdist.linux-x86_64/egg/brainspace/datasets/matrices/holdout_group
# copying build/lib/brainspace/datasets/matrices/holdout_group/schaefer_200_mean_connectivity_matrix.csv -> build/bdist.linux-x86_64/egg/brainspace/datasets/matrices/holdout_group
# copying build/lib/brainspace/datasets/matrices/holdout_group/schaefer_400_mean_connectivity_matrix.csv -> build/bdist.linux-x86_64/egg/brainspace/datasets/matrices/holdout_group
# copying build/lib/brainspace/datasets/matrices/holdout_group/vosdewael_200_mean_connectivity_matrix.csv -> build/bdist.linux-x86_64/egg/brainspace/datasets/matrices/holdout_group
# copying build/lib/brainspace/datasets/matrices/holdout_group/vosdewael_100_mean_connectivity_matrix.csv -> build/bdist.linux-x86_64/egg/brainspace/datasets/matrices/holdout_group
# copying build/lib/brainspace/datasets/matrices/holdout_group/vosdewael_400_mean_connectivity_matrix.csv -> build/bdist.linux-x86_64/egg/brainspace/datasets/matrices/holdout_group
# copying build/lib/brainspace/datasets/matrices/holdout_group/vosdewael_300_mean_connectivity_matrix.csv -> build/bdist.linux-x86_64/egg/brainspace/datasets/matrices/holdout_group
# copying build/lib/brainspace/datasets/matrices/holdout_group/schaefer_100_mean_connectivity_matrix.csv -> build/bdist.linux-x86_64/egg/brainspace/datasets/matrices/holdout_group
# copying build/lib/brainspace/datasets/matrices/holdout_group/schaefer_300_mean_connectivity_matrix.csv -> build/bdist.linux-x86_64/egg/brainspace/datasets/matrices/holdout_group
# creating build/bdist.linux-x86_64/egg/brainspace/datasets/matrices/individual
# copying build/lib/brainspace/datasets/matrices/individual/HCP_393247_minimum_schaefer_100.csv -> build/bdist.linux-x86_64/egg/brainspace/datasets/matrices/individual
# copying build/lib/brainspace/datasets/matrices/individual/HCP_275645_maximum_schaefer_400.csv -> build/bdist.linux-x86_64/egg/brainspace/datasets/matrices/individual
# copying build/lib/brainspace/datasets/matrices/individual/HCP_151425_median_vosdewael_400.csv -> build/bdist.linux-x86_64/egg/brainspace/datasets/matrices/individual
# copying build/lib/brainspace/datasets/matrices/individual/HCP_188347_maximum_schaefer_200.csv -> build/bdist.linux-x86_64/egg/brainspace/datasets/matrices/individual
# copying build/lib/brainspace/datasets/matrices/individual/HCP_899885_median_schaefer_100.csv -> build/bdist.linux-x86_64/egg/brainspace/datasets/matrices/individual
# copying build/lib/brainspace/datasets/matrices/individual/HCP_393247_minimum_vosdewael_200.csv -> build/bdist.linux-x86_64/egg/brainspace/datasets/matrices/individual
# copying build/lib/brainspace/datasets/matrices/individual/HCP_387959_maximum_vosdewael_400.csv -> build/bdist.linux-x86_64/egg/brainspace/datasets/matrices/individual
# copying build/lib/brainspace/datasets/matrices/individual/HCP_208024_median_vosdewael_100.csv -> build/bdist.linux-x86_64/egg/brainspace/datasets/matrices/individual
# copying build/lib/brainspace/datasets/matrices/individual/HCP_246133_maximum_vosdewael_100.csv -> build/bdist.linux-x86_64/egg/brainspace/datasets/matrices/individual
# copying build/lib/brainspace/datasets/matrices/individual/HCP_395251_median_schaefer_200.csv -> build/bdist.linux-x86_64/egg/brainspace/datasets/matrices/individual
# copying build/lib/brainspace/datasets/matrices/individual/HCP_784565_median_vosdewael_200.csv -> build/bdist.linux-x86_64/egg/brainspace/datasets/matrices/individual
# copying build/lib/brainspace/datasets/matrices/individual/HCP_123824_median_vosdewael_300.csv -> build/bdist.linux-x86_64/egg/brainspace/datasets/matrices/individual
# copying build/lib/brainspace/datasets/matrices/individual/HCP_149236_maximum_vosdewael_200.csv -> build/bdist.linux-x86_64/egg/brainspace/datasets/matrices/individual
# copying build/lib/brainspace/datasets/matrices/individual/HCP_153025_minimum_vosdewael_400.csv -> build/bdist.linux-x86_64/egg/brainspace/datasets/matrices/individual
# copying build/lib/brainspace/datasets/matrices/individual/HCP_124624_minimum_schaefer_200.csv -> build/bdist.linux-x86_64/egg/brainspace/datasets/matrices/individual
# copying build/lib/brainspace/datasets/matrices/individual/HCP_124624_maximum_schaefer_300.csv -> build/bdist.linux-x86_64/egg/brainspace/datasets/matrices/individual
# copying build/lib/brainspace/datasets/matrices/individual/HCP_175540_minimum_schaefer_300.csv -> build/bdist.linux-x86_64/egg/brainspace/datasets/matrices/individual
# copying build/lib/brainspace/datasets/matrices/individual/HCP_958976_median_schaefer_300.csv -> build/bdist.linux-x86_64/egg/brainspace/datasets/matrices/individual
# copying build/lib/brainspace/datasets/matrices/individual/HCP_142828_minimum_schaefer_400.csv -> build/bdist.linux-x86_64/egg/brainspace/datasets/matrices/individual
# copying build/lib/brainspace/datasets/matrices/individual/HCP_169949_median_schaefer_400.csv -> build/bdist.linux-x86_64/egg/brainspace/datasets/matrices/individual
# copying build/lib/brainspace/datasets/matrices/individual/HCP_149236_minimum_vosdewael_100.csv -> build/bdist.linux-x86_64/egg/brainspace/datasets/matrices/individual
# copying build/lib/brainspace/datasets/matrices/individual/HCP_111009_maximum_vosdewael_300.csv -> build/bdist.linux-x86_64/egg/brainspace/datasets/matrices/individual
# copying build/lib/brainspace/datasets/matrices/individual/HCP_144125_maximum_schaefer_100.csv -> build/bdist.linux-x86_64/egg/brainspace/datasets/matrices/individual
# copying build/lib/brainspace/datasets/matrices/individual/HCP_958976_minimum_vosdewael_300.csv -> build/bdist.linux-x86_64/egg/brainspace/datasets/matrices/individual
# creating build/bdist.linux-x86_64/egg/brainspace/datasets/parcellations
# copying build/lib/brainspace/datasets/parcellations/vosdewael_100_conte69.csv -> build/bdist.linux-x86_64/egg/brainspace/datasets/parcellations
# copying build/lib/brainspace/datasets/parcellations/schaefer_300_conte69.csv -> build/bdist.linux-x86_64/egg/brainspace/datasets/parcellations
# copying build/lib/brainspace/datasets/parcellations/vosdewael_200_conte69.csv -> build/bdist.linux-x86_64/egg/brainspace/datasets/parcellations
# copying build/lib/brainspace/datasets/parcellations/vosdewael_300_conte69.csv -> build/bdist.linux-x86_64/egg/brainspace/datasets/parcellations
# copying build/lib/brainspace/datasets/parcellations/vosdewael_400_conte69.csv -> build/bdist.linux-x86_64/egg/brainspace/datasets/parcellations
# copying build/lib/brainspace/datasets/parcellations/schaefer_200_conte69.csv -> build/bdist.linux-x86_64/egg/brainspace/datasets/parcellations
# copying build/lib/brainspace/datasets/parcellations/schaefer_400_conte69.csv -> build/bdist.linux-x86_64/egg/brainspace/datasets/parcellations
# copying build/lib/brainspace/datasets/parcellations/mesulam_conte69.csv -> build/bdist.linux-x86_64/egg/brainspace/datasets/parcellations
# copying build/lib/brainspace/datasets/parcellations/schaefer_100_conte69.csv -> build/bdist.linux-x86_64/egg/brainspace/datasets/parcellations
# creating build/bdist.linux-x86_64/egg/brainspace/vtk_interface
# creating build/bdist.linux-x86_64/egg/brainspace/vtk_interface/io_support
# copying build/lib/brainspace/vtk_interface/io_support/gifti_support.py -> build/bdist.linux-x86_64/egg/brainspace/vtk_interface/io_support
# copying build/lib/brainspace/vtk_interface/io_support/freesurfer_support.py -> build/bdist.linux-x86_64/egg/brainspace/vtk_interface/io_support
# copying build/lib/brainspace/vtk_interface/io_support/__init__.py -> build/bdist.linux-x86_64/egg/brainspace/vtk_interface/io_support
# copying build/lib/brainspace/vtk_interface/pipeline.py -> build/bdist.linux-x86_64/egg/brainspace/vtk_interface
# copying build/lib/brainspace/vtk_interface/__init__.py -> build/bdist.linux-x86_64/egg/brainspace/vtk_interface
# copying build/lib/brainspace/vtk_interface/checks.py -> build/bdist.linux-x86_64/egg/brainspace/vtk_interface
# copying build/lib/brainspace/vtk_interface/decorators.py -> build/bdist.linux-x86_64/egg/brainspace/vtk_interface
# creating build/bdist.linux-x86_64/egg/brainspace/vtk_interface/wrappers
# copying build/lib/brainspace/vtk_interface/wrappers/algorithm.py -> build/bdist.linux-x86_64/egg/brainspace/vtk_interface/wrappers
# copying build/lib/brainspace/vtk_interface/wrappers/renderer.py -> build/bdist.linux-x86_64/egg/brainspace/vtk_interface/wrappers
# copying build/lib/brainspace/vtk_interface/wrappers/lookup_table.py -> build/bdist.linux-x86_64/egg/brainspace/vtk_interface/wrappers
# copying build/lib/brainspace/vtk_interface/wrappers/data_object.py -> build/bdist.linux-x86_64/egg/brainspace/vtk_interface/wrappers
# copying build/lib/brainspace/vtk_interface/wrappers/utils.py -> build/bdist.linux-x86_64/egg/brainspace/vtk_interface/wrappers
# copying build/lib/brainspace/vtk_interface/wrappers/property.py -> build/bdist.linux-x86_64/egg/brainspace/vtk_interface/wrappers
# copying build/lib/brainspace/vtk_interface/wrappers/misc.py -> build/bdist.linux-x86_64/egg/brainspace/vtk_interface/wrappers
# copying build/lib/brainspace/vtk_interface/wrappers/base.py -> build/bdist.linux-x86_64/egg/brainspace/vtk_interface/wrappers
# copying build/lib/brainspace/vtk_interface/wrappers/__init__.py -> build/bdist.linux-x86_64/egg/brainspace/vtk_interface/wrappers
# copying build/lib/brainspace/vtk_interface/wrappers/actor.py -> build/bdist.linux-x86_64/egg/brainspace/vtk_interface/wrappers
# creating build/bdist.linux-x86_64/egg/brainspace/gradient
# copying build/lib/brainspace/gradient/gradient.py -> build/bdist.linux-x86_64/egg/brainspace/gradient
# copying build/lib/brainspace/gradient/utils.py -> build/bdist.linux-x86_64/egg/brainspace/gradient
# copying build/lib/brainspace/gradient/alignment.py -> build/bdist.linux-x86_64/egg/brainspace/gradient
# copying build/lib/brainspace/gradient/__init__.py -> build/bdist.linux-x86_64/egg/brainspace/gradient
# copying build/lib/brainspace/gradient/embedding.py -> build/bdist.linux-x86_64/egg/brainspace/gradient
# copying build/lib/brainspace/gradient/kernels.py -> build/bdist.linux-x86_64/egg/brainspace/gradient
# creating build/bdist.linux-x86_64/egg/brainspace/examples
# copying build/lib/brainspace/examples/plot_tutorial0.py -> build/bdist.linux-x86_64/egg/brainspace/examples
# copying build/lib/brainspace/examples/plot_tutorial3.py -> build/bdist.linux-x86_64/egg/brainspace/examples
# copying build/lib/brainspace/examples/plot_tutorial2.py -> build/bdist.linux-x86_64/egg/brainspace/examples
# copying build/lib/brainspace/examples/plot_tutorial1.py -> build/bdist.linux-x86_64/egg/brainspace/examples
# copying build/lib/brainspace/examples/__init__.py -> build/bdist.linux-x86_64/egg/brainspace/examples
# creating build/bdist.linux-x86_64/egg/brainspace/plotting
# copying build/lib/brainspace/plotting/utils_qt.py -> build/bdist.linux-x86_64/egg/brainspace/plotting
# copying build/lib/brainspace/plotting/colormaps.py -> build/bdist.linux-x86_64/egg/brainspace/plotting
# copying build/lib/brainspace/plotting/surface_plotting.py -> build/bdist.linux-x86_64/egg/brainspace/plotting
# copying build/lib/brainspace/plotting/defaults_plotting.py -> build/bdist.linux-x86_64/egg/brainspace/plotting
# copying build/lib/brainspace/plotting/utils.py -> build/bdist.linux-x86_64/egg/brainspace/plotting
# copying build/lib/brainspace/plotting/base.py -> build/bdist.linux-x86_64/egg/brainspace/plotting
# copying build/lib/brainspace/plotting/__init__.py -> build/bdist.linux-x86_64/egg/brainspace/plotting
# copying build/lib/brainspace/plotting/sphinx_gallery_scrapper.py -> build/bdist.linux-x86_64/egg/brainspace/plotting
# copying build/lib/brainspace/_version.py -> build/bdist.linux-x86_64/egg/brainspace
# creating build/bdist.linux-x86_64/egg/brainspace/tests
# copying build/lib/brainspace/tests/test_wrapping.py -> build/bdist.linux-x86_64/egg/brainspace/tests
# copying build/lib/brainspace/tests/test_mesh.py -> build/bdist.linux-x86_64/egg/brainspace/tests
# copying build/lib/brainspace/tests/test_gradient.py -> build/bdist.linux-x86_64/egg/brainspace/tests
# copying build/lib/brainspace/tests/test_plotting.py -> build/bdist.linux-x86_64/egg/brainspace/tests
# copying build/lib/brainspace/tests/test_datasets.py -> build/bdist.linux-x86_64/egg/brainspace/tests
# copying build/lib/brainspace/tests/test_parcellation.py -> build/bdist.linux-x86_64/egg/brainspace/tests
# copying build/lib/brainspace/tests/test_null_models.py -> build/bdist.linux-x86_64/egg/brainspace/tests
# copying build/lib/brainspace/tests/__init__.py -> build/bdist.linux-x86_64/egg/brainspace/tests
# copying build/lib/brainspace/__init__.py -> build/bdist.linux-x86_64/egg/brainspace
# byte-compiling build/bdist.linux-x86_64/egg/brainspace/mesh/array_operations.py to array_operations.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/brainspace/mesh/mesh_io.py to mesh_io.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/brainspace/mesh/mesh_creation.py to mesh_creation.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/brainspace/mesh/__init__.py to __init__.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/brainspace/mesh/mesh_cluster.py to mesh_cluster.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/brainspace/mesh/mesh_operations.py to mesh_operations.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/brainspace/mesh/mesh_correspondence.py to mesh_correspondence.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/brainspace/mesh/mesh_elements.py to mesh_elements.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/brainspace/null_models/moran.py to moran.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/brainspace/null_models/variogram.py to variogram.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/brainspace/null_models/__init__.py to __init__.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/brainspace/null_models/spin.py to spin.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/brainspace/utils/parcellation.py to parcellation.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/brainspace/utils/__init__.py to __init__.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/brainspace/vtk_interface/io_support/gifti_support.py to gifti_support.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/brainspace/vtk_interface/io_support/freesurfer_support.py to freesurfer_support.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/brainspace/vtk_interface/io_support/__init__.py to __init__.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/brainspace/vtk_interface/pipeline.py to pipeline.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/brainspace/vtk_interface/__init__.py to __init__.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/brainspace/vtk_interface/checks.py to checks.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/brainspace/vtk_interface/decorators.py to decorators.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/brainspace/vtk_interface/wrappers/algorithm.py to algorithm.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/brainspace/vtk_interface/wrappers/renderer.py to renderer.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/brainspace/vtk_interface/wrappers/lookup_table.py to lookup_table.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/brainspace/vtk_interface/wrappers/data_object.py to data_object.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/brainspace/vtk_interface/wrappers/utils.py to utils.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/brainspace/vtk_interface/wrappers/property.py to property.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/brainspace/vtk_interface/wrappers/misc.py to misc.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/brainspace/vtk_interface/wrappers/base.py to base.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/brainspace/vtk_interface/wrappers/__init__.py to __init__.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/brainspace/vtk_interface/wrappers/actor.py to actor.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/brainspace/gradient/gradient.py to gradient.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/brainspace/gradient/utils.py to utils.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/brainspace/gradient/alignment.py to alignment.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/brainspace/gradient/__init__.py to __init__.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/brainspace/gradient/embedding.py to embedding.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/brainspace/gradient/kernels.py to kernels.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/brainspace/examples/plot_tutorial0.py to plot_tutorial0.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/brainspace/examples/plot_tutorial3.py to plot_tutorial3.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/brainspace/examples/plot_tutorial2.py to plot_tutorial2.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/brainspace/examples/plot_tutorial1.py to plot_tutorial1.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/brainspace/examples/__init__.py to __init__.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/brainspace/plotting/utils_qt.py to utils_qt.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/brainspace/plotting/colormaps.py to colormaps.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/brainspace/plotting/surface_plotting.py to surface_plotting.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/brainspace/plotting/defaults_plotting.py to defaults_plotting.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/brainspace/plotting/utils.py to utils.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/brainspace/plotting/base.py to base.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/brainspace/plotting/__init__.py to __init__.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/brainspace/plotting/sphinx_gallery_scrapper.py to sphinx_gallery_scrapper.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/brainspace/_version.py to _version.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/brainspace/tests/test_wrapping.py to test_wrapping.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/brainspace/tests/test_mesh.py to test_mesh.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/brainspace/tests/test_gradient.py to test_gradient.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/brainspace/tests/test_plotting.py to test_plotting.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/brainspace/tests/test_datasets.py to test_datasets.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/brainspace/tests/test_parcellation.py to test_parcellation.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/brainspace/tests/test_null_models.py to test_null_models.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/brainspace/tests/__init__.py to __init__.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/brainspace/__init__.py to __init__.cpython-39.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying brainspace.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying brainspace.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying brainspace.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying brainspace.egg-info/not-zip-safe -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying brainspace.egg-info/requires.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying brainspace.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# creating 'dist/brainspace-0.1.4-py3.9.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing brainspace-0.1.4-py3.9.egg
# removing '/home/romy.beaute/anaconda3/lib/python3.9/site-packages/brainspace-0.1.4-py3.9.egg' (and everything under it)
# creating /home/romy.beaute/anaconda3/lib/python3.9/site-packages/brainspace-0.1.4-py3.9.egg
# Extracting brainspace-0.1.4-py3.9.egg to /home/romy.beaute/anaconda3/lib/python3.9/site-packages
# brainspace 0.1.4 is already the active version in easy-install.pth
#
# Installed /home/romy.beaute/anaconda3/lib/python3.9/site-packages/brainspace-0.1.4-py3.9.egg
# Processing dependencies for brainspace==0.1.4
# Searching for pandas==1.4.2
# Best match: pandas 1.4.2
# Adding pandas 1.4.2 to easy-install.pth file
#
# Using /home/romy.beaute/anaconda3/lib/python3.9/site-packages
# Searching for Pillow==9.0.1
# Best match: Pillow 9.0.1
# Adding Pillow 9.0.1 to easy-install.pth file
#
# Using /home/romy.beaute/anaconda3/lib/python3.9/site-packages
# Searching for nibabel==3.2.2
# Best match: nibabel 3.2.2
# Adding nibabel 3.2.2 to easy-install.pth file
# Installing nib-conform script to /home/romy.beaute/anaconda3/bin
# Installing nib-dicomfs script to /home/romy.beaute/anaconda3/bin
# Installing nib-diff script to /home/romy.beaute/anaconda3/bin
# Installing nib-ls script to /home/romy.beaute/anaconda3/bin
# Installing nib-nifti-dx script to /home/romy.beaute/anaconda3/bin
# Installing nib-roi script to /home/romy.beaute/anaconda3/bin
# Installing nib-stats script to /home/romy.beaute/anaconda3/bin
# Installing nib-tck2trk script to /home/romy.beaute/anaconda3/bin
# Installing nib-trk2tck script to /home/romy.beaute/anaconda3/bin
# Installing parrec2nii script to /home/romy.beaute/anaconda3/bin
#
# Using /home/romy.beaute/anaconda3/lib/python3.9/site-packages
# Searching for vtk==9.1.0
# Best match: vtk 9.1.0
# Adding vtk 9.1.0 to easy-install.pth file
#
# Using /home/romy.beaute/anaconda3/lib/python3.9/site-packages
# Searching for matplotlib==3.5.1
# Best match: matplotlib 3.5.1
# Adding matplotlib 3.5.1 to easy-install.pth file
#
# Using /home/romy.beaute/anaconda3/lib/python3.9/site-packages
# Searching for scikit-learn==1.0.2
# Best match: scikit-learn 1.0.2
# Adding scikit-learn 1.0.2 to easy-install.pth file
#
# Using /home/romy.beaute/anaconda3/lib/python3.9/site-packages
# Searching for scipy==1.7.3
# Best match: scipy 1.7.3
# Adding scipy 1.7.3 to easy-install.pth file
#
# Using /home/romy.beaute/anaconda3/lib/python3.9/site-packages
# Searching for numpy==1.21.5
# Best match: numpy 1.21.5
# Adding numpy 1.21.5 to easy-install.pth file
# Installing f2py script to /home/romy.beaute/anaconda3/bin
# Installing f2py3 script to /home/romy.beaute/anaconda3/bin
# Installing f2py3.9 script to /home/romy.beaute/anaconda3/bin
#
# Using /home/romy.beaute/anaconda3/lib/python3.9/site-packages
# Searching for pytz==2022.1
# Best match: pytz 2022.1
# Processing pytz-2022.1-py3.9.egg
# pytz 2022.1 is already the active version in easy-install.pth
#
# Using /home/romy.beaute/anaconda3/lib/python3.9/site-packages/pytz-2022.1-py3.9.egg
# Searching for python-dateutil==2.8.2
# Best match: python-dateutil 2.8.2
# Adding python-dateutil 2.8.2 to easy-install.pth file
#
# Using /home/romy.beaute/anaconda3/lib/python3.9/site-packages
# Searching for setuptools==61.2.0
# Best match: setuptools 61.2.0
# Adding setuptools 61.2.0 to easy-install.pth file
#
# Using /home/romy.beaute/anaconda3/lib/python3.9/site-packages
# Searching for packaging==21.3
# Best match: packaging 21.3
# Adding packaging 21.3 to easy-install.pth file
#
# Using /home/romy.beaute/anaconda3/lib/python3.9/site-packages
# Searching for wslink==1.6.5
# Best match: wslink 1.6.5
# Adding wslink 1.6.5 to easy-install.pth file
#
# Using /home/romy.beaute/anaconda3/lib/python3.9/site-packages
# Searching for pyparsing==3.0.4
# Best match: pyparsing 3.0.4
# Adding pyparsing 3.0.4 to easy-install.pth file
#
# Using /home/romy.beaute/anaconda3/lib/python3.9/site-packages
# Searching for kiwisolver==1.3.2
# Best match: kiwisolver 1.3.2
# Adding kiwisolver 1.3.2 to easy-install.pth file
#
# Using /home/romy.beaute/anaconda3/lib/python3.9/site-packages
# Searching for fonttools==4.25.0
# Best match: fonttools 4.25.0
# Adding fonttools 4.25.0 to easy-install.pth file
# Installing fonttools script to /home/romy.beaute/anaconda3/bin
# Installing pyftmerge script to /home/romy.beaute/anaconda3/bin
# Installing pyftsubset script to /home/romy.beaute/anaconda3/bin
# Installing ttx script to /home/romy.beaute/anaconda3/bin
#
# Using /home/romy.beaute/anaconda3/lib/python3.9/site-packages
# Searching for cycler==0.11.0
# Best match: cycler 0.11.0
# Adding cycler 0.11.0 to easy-install.pth file
#
# Using /home/romy.beaute/anaconda3/lib/python3.9/site-packages
# Searching for threadpoolctl==2.2.0
# Best match: threadpoolctl 2.2.0
# Adding threadpoolctl 2.2.0 to easy-install.pth file
#
# Using /home/romy.beaute/anaconda3/lib/python3.9/site-packages
# Searching for joblib==1.1.0
# Best match: joblib 1.1.0
# Adding joblib 1.1.0 to easy-install.pth file
#
# Using /home/romy.beaute/anaconda3/lib/python3.9/site-packages
# Searching for six==1.16.0
# Best match: six 1.16.0
# Adding six 1.16.0 to easy-install.pth file
#
# Using /home/romy.beaute/anaconda3/lib/python3.9/site-packages
# Searching for aiohttp==3.8.1
# Best match: aiohttp 3.8.1
# Adding aiohttp 3.8.1 to easy-install.pth file
#
# Using /home/romy.beaute/anaconda3/lib/python3.9/site-packages
# Searching for aiosignal==1.2.0
# Best match: aiosignal 1.2.0
# Adding aiosignal 1.2.0 to easy-install.pth file
#
# Using /home/romy.beaute/anaconda3/lib/python3.9/site-packages
# Searching for frozenlist==1.2.0
# Best match: frozenlist 1.2.0
# Adding frozenlist 1.2.0 to easy-install.pth file
#
# Using /home/romy.beaute/anaconda3/lib/python3.9/site-packages
# Searching for yarl==1.6.3
# Best match: yarl 1.6.3
# Adding yarl 1.6.3 to easy-install.pth file
#
# Using /home/romy.beaute/anaconda3/lib/python3.9/site-packages
# Searching for async-timeout==4.0.1
# Best match: async-timeout 4.0.1
# Adding async-timeout 4.0.1 to easy-install.pth file
#
# Using /home/romy.beaute/anaconda3/lib/python3.9/site-packages
# Searching for multidict==5.2.0
# Best match: multidict 5.2.0
# Adding multidict 5.2.0 to easy-install.pth file
#
# Using /home/romy.beaute/anaconda3/lib/python3.9/site-packages
# Searching for charset-normalizer==2.0.4
# Best match: charset-normalizer 2.0.4
# Adding charset-normalizer 2.0.4 to easy-install.pth file
# Installing normalizer script to /home/romy.beaute/anaconda3/bin
#
# Using /home/romy.beaute/anaconda3/lib/python3.9/site-packages
# Searching for attrs==21.4.0
# Best match: attrs 21.4.0
# Adding attrs 21.4.0 to easy-install.pth file
#
# Using /home/romy.beaute/anaconda3/lib/python3.9/site-packages
# Searching for idna==3.3
# Best match: idna 3.3
# Adding idna 3.3 to easy-install.pth file
#
# Using /home/romy.beaute/anaconda3/lib/python3.9/site-packages
# Searching for typing-extensions==4.1.1
# Best match: typing-extensions 4.1.1
# Adding typing-extensions 4.1.1 to easy-install.pth file
#
# Using /home/romy.beaute/anaconda3/lib/python3.9/site-packages
# Finished processing dependencies for brainspace==0.1.4

# %% [markdown]
# ## Import the dataset as timeseries
#
#
# NB : Timeseries (data) should be a numpy array with the dimensions: nodes x timepoints

# %%
import sys, os
import numpy as np
import nibabel as nib
import brainspace
import matplotlib
import sklearn

# %%
sys.path.append('/mnt/data/romy/hypnomed/git/diffusion_embedding/scripts_reordered') 

from load_fs import *

sub = 'sub-01'
ses = 'ses-001'
state = 'rs_run-1'

freesurfer_output = '/mnt/data/romy/hypnomed/MRI_raw/BIDS/derivatives/fmriprep-latest/sourcedata/freesurfer'
vol2surf_path = "/mnt/data/romy/hypnomed/git/diffusion_embedding/vol2surf_derivatives/{}/{}".format(sub,ses)
labels = []
timeseries = [None] * 2

for i, h in enumerate(['lh', 'rh']):
    filename = os.path.join(vol2surf_path,'{}_{}_task-{}.fsa5.{}.mgz'.format(sub,ses,state,h))
    timeseries[i] = nib.load(filename.format(h)).get_fdata().squeeze()
    print(timeseries[i].shape) 
    labels.append(nib.freesurfer.read_label(f'{freesurfer_output}/fsaverage5/label/{h}.cortex.label'))
timeseries = np.vstack(timeseries)

print(' - Original shape timeseries : {} --> ie {} nodes x {} timepoints'.format(timeseries.shape,timeseries.shape[0],timeseries.shape[1]))
print(' - Label R + Label L : {} + {} nodes = {} nodes '.format(len(labels[0]),len(labels[1]),len(labels[0])+len(labels[1])))
# Out:
# (10242, 235)
# (10242, 235)
#  - Original shape timeseries : (20484, 235) --> ie 20484 nodes x 235 timepoints
#  - Label R + Label L : 9354 + 9361 nodes = 18715 nodes

# %% [markdown]
# *Compare wih shape from data loaded in tuto*

# %%
from brainspace.datasets import fetch_timeseries_preprocessing
ts_tuto = fetch_timeseries_preprocessing()
ts_tuto.shape
# Out:
# (20484, 652)

# %% [markdown]
# ## Confound regression
#
#
# Strategy to select and load confounds from fMRIPrep (based on past literature with limited parameters for user customisation).
#
# => use "simple" preset denoising strategy (as denoising strategy commonly used in resting state functional connectivity)
#
# => global signal regression : remove confounds without compromising the temporal degrees of freedom.
#
#
# - https://nilearn.github.io/stable/modules/generated/nilearn.interfaces.fmriprep.load_confounds_strategy.html (COUFOUNDS Nilearn)
# - https://nilearn.github.io/stable/glossary.html#term-fMRIPrep (fMRIPREP)

# %%
from nilearn.interfaces.fmriprep import load_confounds_strategy
from nilearn import signal

fmriprep_output = '/mnt/data/romy/hypnomed/MRI_raw/BIDS/derivatives/fmriprep-latest/{}/ses-001/func'.format(sub)
fmriprep_simple = '{}_ses-001_task-{}_space-T1w_desc-preproc_bold.nii.gz'.format(sub,state)
fmriprep_aroma = '{}_ses-001_task-{}_space-MNI152NLin6Asym_desc-smoothAROMAnonaggr_bold.nii.gz'.format(sub,state)

confounds_out_simple = load_confounds_strategy(os.path.join(fmriprep_output,fmriprep_simple),
                                        denoise_strategy='simple')[0]

print(confounds_out_simple.shape)

confounds_out_simple = load_confounds_strategy(os.path.join(fmriprep_output,fmriprep_simple),
                                        denoise_strategy='simple')[0]

print(confounds_out_simple.shape)
# Out:
# (235, 33)
# (20484, 235)

# %%
confounds_out_AROMA = load_confounds_strategy(os.path.join(fmriprep_output,fmriprep_file),
                                        denoise_strategy='ica_aroma')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/romy.beaute/projects/hypnomed/BrainSpace/tuto1.ipynb Cell 10 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://ssh-remote%2B10.69.168.62/home/romy.beaute/projects/hypnomed/BrainSpace/tuto1.ipynb#X36sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> confounds_out_AROMA = load_confounds_strategy(os.path.join(fmriprep_output,fmriprep_file),
#       <a href='vscode-notebook-cell://ssh-remote%2B10.69.168.62/home/romy.beaute/projects/hypnomed/BrainSpace/tuto1.ipynb#X36sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a>                                         denoise_strategy='ica_aroma')
#
# File ~/anaconda3/lib/python3.9/site-packages/nilearn/interfaces/fmriprep/load_confounds_strategy.py:221, in load_confounds_strategy(img_files, denoise_strategy, **kwargs)
#     216 if not_needed:
#     217     warnings.warn("The following parameters are not needed for the "
#     218                   f"selected strategy '{denoise_strategy}': {not_needed}; "
#     219                   f"parameters accepted: {check_parameters}"
#     220                   )
# --> 221 return load_confounds(img_files, **user_parameters)
#
# File ~/anaconda3/lib/python3.9/site-packages/nilearn/interfaces/fmriprep/load_confounds.py:272, in load_confounds(img_files, strategy, motion, scrub, fd_threshold, std_dvars_threshold, wm_csf, global_signal, compcor, n_compcor, ica_aroma, demean)
#     270 sample_mask_out = []
#     271 for file in img_files:
# --> 272     sample_mask, conf = _load_single(
#     273         file, strategy, demean,
#     274         motion=motion,
#     275         scrub=scrub,
#     276         fd_threshold=fd_threshold,
#     277         std_dvars_threshold=std_dvars_threshold,
#     278         wm_csf=wm_csf,
#     279         global_signal=global_signal,
#     280         compcor=compcor, n_compcor=n_compcor,
#     281         ica_aroma=ica_aroma)
#     282     confounds_out.append(conf)
#     283     sample_mask_out.append(sample_mask)
#
# File ~/anaconda3/lib/python3.9/site-packages/nilearn/interfaces/fmriprep/load_confounds.py:303, in _load_single(confounds_raw, strategy, demean, **kargs)
#     297 flag_acompcor = ("compcor" in strategy) and (
#     298     "anat" in kargs.get("compcor")
#     299 )
#     300 flag_full_aroma = ("ica_aroma" in strategy) and (
#     301     kargs.get("ica_aroma") == "full"
#     302 )
# --> 303 confounds_raw, meta_json = _confounds_to_df(
#     304     confounds_raw, flag_acompcor, flag_full_aroma
#     305 )
#     307 missing = {"confounds": [], "keywords": []}
#     308 # always check non steady state volumes are loaded
#
# File ~/anaconda3/lib/python3.9/site-packages/nilearn/interfaces/fmriprep/load_confounds_utils.py:202, in _confounds_to_df(image_file, flag_acompcor, flag_full_aroma)
#     200 def _confounds_to_df(image_file, flag_acompcor, flag_full_aroma):
#     201     """Load raw confounds and associated metadata."""
# --> 202     _check_images(image_file, flag_full_aroma)
#     203     confounds_raw_path = _get_file_name(image_file)
#     204     confounds_json = _get_json(confounds_raw_path, flag_acompcor)
#
# File ~/anaconda3/lib/python3.9/site-packages/nilearn/interfaces/fmriprep/load_confounds_utils.py:197, in _check_images(image_file, flag_full_aroma)
#     195     valid_img, error_message = _ext_validator([image_file], ext)
#     196 if not valid_img:
# --> 197     raise ValueError(error_message)
#
# ValueError: Input must be ~desc-smoothAROMAnonaggr_bold for full ICA-AROMA strategy.

# %%
confounds_out
# Out:
#      cosine00  cosine01  cosine02  cosine03  cosine04  cosine05  cosine06  \
# 0    0.092251  0.092245  0.092235  0.092220  0.092202  0.092179  0.092152
# 1    0.092235  0.092179  0.092086  0.091957  0.091790  0.091586  0.091346
# 2    0.092202  0.092047  0.091790  0.091430  0.090968  0.090405  0.089740
# 3    0.092152  0.091849  0.091346  0.090642  0.089740  0.088642  0.087349
# 4    0.092086  0.091586  0.090755  0.089595  0.088111  0.086309  0.084194
# ..        ...       ...       ...       ...       ...       ...       ...
# 230 -0.092086  0.091586 -0.090755  0.089595 -0.088111  0.086309 -0.084194
# 231 -0.092152  0.091849 -0.091346  0.090642 -0.089740  0.088642 -0.087349
# 232 -0.092202  0.092047 -0.091790  0.091430 -0.090968  0.090405 -0.089740
# 233 -0.092235  0.092179 -0.092086  0.091957 -0.091790  0.091586 -0.091346
# 234 -0.092251  0.092245 -0.092235  0.092220 -0.092202  0.092179 -0.092152
#
#             csf     rot_x  rot_x_derivative1  ...  trans_x_power2   trans_y  \
# 0    211.381513  0.023669           0.000056  ...       -0.111850 -0.046145
# 1     54.460432  0.023546           0.000056  ...       -0.111438 -0.020865
# 2     72.657765  0.023348          -0.000020  ...       -0.111452 -0.014237
# 3    179.543399  0.023344           0.000175  ...       -0.111848 -0.046187
# 4    105.361708  0.023016          -0.000150  ...       -0.111848 -0.000966
# ..          ...       ...                ...  ...             ...       ...
# 230  -29.715734 -0.017700          -0.000052  ...        0.118527 -0.006660
# 231  -66.521009 -0.017884          -0.000006  ...        0.118599  0.009142
# 232  -99.798139 -0.017373           0.000690  ...        0.107646 -0.023645
# 233  -72.792664 -0.017844          -0.000292  ...        0.094375 -0.019612
# 234  -67.907118 -0.018217          -0.000194  ...        0.124482 -0.003802
#
#      trans_y_derivative1  trans_y_derivative1_power2  trans_y_power2  \
# 0               0.024992                    0.000136        0.002945
# 1               0.024992                    0.000136       -0.000085
# 2               0.006341                   -0.000459       -0.000668
# 3              -0.032238                    0.000518        0.002951
# 4               0.044933                    0.001542       -0.001571
# ..                   ...                         ...             ...
# 230             0.017184                   -0.000198       -0.001227
# 231             0.015515                   -0.000254       -0.002023
# 232            -0.033075                    0.000572        0.000186
# 233             0.003745                   -0.000487       -0.000202
# 234             0.015523                   -0.000253       -0.001408
#
#       trans_z  trans_z_derivative1  trans_z_derivative1_power2  \
# 0    0.050773             0.040857                    0.000374
# 1    0.090898             0.040857                    0.000374
# 2    0.070590            -0.019578                   -0.000824
# 3    0.049595            -0.020264                   -0.000796
# 4    0.080438             0.031574                   -0.000285
# ..        ...                  ...                         ...
# 230 -0.160498             0.064027                    0.002770
# 231 -0.121964             0.039265                    0.000248
# 232 -0.190593            -0.067898                    0.003473
# 233 -0.208576            -0.017252                   -0.000913
# 234 -0.161147             0.048160                    0.001013
#
#      trans_z_power2  white_matter
# 0         -0.020487     41.268159
# 1         -0.024370     41.299174
# 2         -0.022807     59.523952
# 3         -0.020324     66.407435
# 4         -0.023668     68.429112
# ..              ...           ...
# 230        0.053073    -34.161428
# 231        0.033000    -42.770629
# 232        0.070815    -44.753763
# 233        0.082281    -42.383331
# 234        0.053436    -56.837418
#
# [235 rows x 33 columns]

# %%
# Confound regression
clean_ts = signal.clean(timeseries.T, confounds=confounds_out).T
clean_ts.shape
# Out:
# (20484, 235)

# %% [markdown]
# *Compare wih shape from data loaded in tuto*

# %%
from brainspace.datasets import load_confounds_preprocessing
confounds_out_tuto = load_confounds_preprocessing()
confounds_out_tuto.shape
# Out:
# (652, 29)

# %%
label = nib.freesurfer.read_label(f'{freesurfer_output}/fsaverage5/label/{h}.cortex.label')

# %%
# Out:
# (20484, 652)

# %%
from load_fs import load_fs

# %%
data = load_fs(sub,ses,state)

# %%
data.shape
# Out:
# (18715, 235)

# %%
ts = []
label = []
for h in ['lh','rh']: #order of hemisphere is important !
    #loop through hemispheres
    ts.append(nib.load(f'{vol2surf_path}/{sub}_{ses}_task-{state}.fsa5.{h}.mgz').get_data().squeeze())
# Out:
# /tmp/ipykernel_2164287/783497625.py:5: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   ts.append(nib.load(f'{vol2surf_path}/{sub}_{ses}_task-{state}.fsa5.{h}.mgz').get_data().squeeze())

# %%
ts
# Out:
# [array([[10932.243 , 10960.968 , 10919.1455, ..., 10996.024 , 11006.026 ,
#          11029.652 ],
#         [13640.841 , 13594.97  , 13698.012 , ..., 13712.899 , 13753.704 ,
#          13721.796 ],
#         [12543.235 , 12536.526 , 12554.685 , ..., 12716.575 , 12758.684 ,
#          12787.699 ],
#         ...,
#         [11553.502 , 11637.631 , 11475.968 , ..., 11605.24  , 11555.416 ,
#          11648.314 ],
#         [11577.567 , 11679.924 , 11489.445 , ..., 11633.264 , 11574.406 ,
#          11651.901 ],
#         [11756.006 , 11855.627 , 11680.64  , ..., 11803.974 , 11768.624 ,
#          11833.498 ]], dtype=float32),
#  array([[13043.551 , 12975.011 , 13040.363 , ..., 12932.149 , 12987.742 ,
#          13013.312 ],
#         [13604.597 , 13532.259 , 13599.715 , ..., 13576.8545, 13536.136 ,
#          13543.137 ],
#         [13175.862 , 13153.214 , 13211.118 , ..., 13286.922 , 13402.007 ,
#          13487.886 ],
#         ...,
#         [ 2425.0957,  2413.5315,  2436.7954, ...,  2399.8787,  2366.5193,
#           2402.7522],
#         [ 3561.8198,  3552.3672,  3582.8188, ...,  3560.1147,  3494.7996,
#           3548.9336],
#         [ 5227.9727,  5221.3687,  5250.87  , ...,  5253.941 ,  5181.2554,
#           5231.245 ]], dtype=float32)]
