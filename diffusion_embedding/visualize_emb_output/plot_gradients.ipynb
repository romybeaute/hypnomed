# %%
# %matplotlib inline 


import matplotlib 
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import matplotlib.image as img
import os
import cv2


#drive.mount('/content/drive')


imtypes = ['blocks','states','scatter_embedded']
imtype = 'blocks'

impath = '/home/romy.beaute/projects/hypnomed/diffusion_embedding/visualize_emb_output/images_gradients/{}/group/Gradient_1'.format(imtype)
impath_inf = '/home/romy.beaute/projects/hypnomed/diffusion_embedding/visualize_emb_output/images_gradients/{}/group/Gradient_1/inflated'.format(imtype)

condition = 'rs-1'

imgs = [img for img in os.listdir(impath) if img.endswith('png')]
imgs_inf = [img for img in os.listdir(impath_inf) if img.endswith('png')]

print(imgs)
print(imgs_inf)
# Out:
# ['PG_run-2_surfmeshL.png', 'PG_run-3_surfmeshR.png', 'PG_run-2_surfmeshR.png', 'PG_run-1_surfmeshL.png', 'PG_run-1_surfmeshR.png', 'PG_run-3_surfmeshL.png']
# ['group_diffusion_map_run-2_rh_Dim#1.png', 'group_diffusion_map_run-3_rh_Dim#1.png', 'group_diffusion_map_run-3_lh_Dim#1.png', 'group_diffusion_map_run-2_lh_Dim#1.png', 'group_diffusion_map_run-1_rh_Dim#1.png', 'group_diffusion_map_run-1_lh_Dim#1.png']

# %%
cond_imgs = [img for img in imgs if 'run-2' in img]
cond_imgs_r = [img for img in cond_imgs if 'R' in img]
cond_imgs_l = [img for img in cond_imgs if 'L' in img]


cond_imgs_inf = [img for img in imgs_inf if 'run-2' in img]
cond_imgs_inf_r = [img for img in cond_imgs_inf if 'rh' in img]
cond_imgs_inf_l = [img for img in cond_imgs_inf if 'rl' in img]

cond_imgs_inf_r
# Out:
# ['group_diffusion_map_run-2_rh_Dim#1.png']

# %%
import cv2


imgslist = []
imgslist.extend([os.path.join(impath,img) for img in imgs ])
images = [cv2.imread(im) for im in imgslist] #reading images


imgslist_inf = []
imgslist_inf.extend([os.path.join(impath_inf,img) for img in imgs ])
images_inf = [cv2.imread(im) for im in imgslist_inf] #reading images
# Out:
# [ WARN:0@168.941] global /io/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/home/romy.beaute/projects/hypnomed/diffusion_embedding/visualize_emb_output/images_gradients/blocks/group/Gradient_1/inflated/PG_run-2_surfmeshL.png'): can't open/read file: check file path/integrity
# [ WARN:0@168.941] global /io/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/home/romy.beaute/projects/hypnomed/diffusion_embedding/visualize_emb_output/images_gradients/blocks/group/Gradient_1/inflated/PG_run-3_surfmeshR.png'): can't open/read file: check file path/integrity
# [ WARN:0@168.941] global /io/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/home/romy.beaute/projects/hypnomed/diffusion_embedding/visualize_emb_output/images_gradients/blocks/group/Gradient_1/inflated/PG_run-2_surfmeshR.png'): can't open/read file: check file path/integrity
# ...

# %%
fig = plt.figure(figsize=(10, 7))

rows = 2
columns = 2
#fig.suptitle('{}'.format(condition), fontsize=16)


# Adds a subplot at the 1st position
fig.add_subplot(rows, columns, 1)

# showing image
plt.imshow(images[0])
plt.axis('off')
plt.title("First")
  
# Adds a subplot at the 2nd position
fig.add_subplot(rows, columns, 2)
  
# showing image
plt.imshow(images[2])
plt.axis('off')
plt.title("Second")
  
# Adds a subplot at the 3rd position
fig.add_subplot(rows, columns, 3)
  
# showing image
plt.imshow(images[1])
plt.axis('off')
plt.title("Third")
  
# Adds a subplot at the 4th position
fig.add_subplot(rows, columns, 4)
  
# showing image
plt.imshow(images[4])
plt.axis('off')
plt.title("Fourth")


fig.show()
